# %%
from python_files.Data_Loader import Data_Loader
from python_files.spalten.Spalten import Spalten
from python_files.Modellauswertung_Dask import Modellauswertung_Dask
from dask.distributed import Client, LocalCluster
from xgboost.dask import DaskXGBClassifier

# %%
cluster = LocalCluster(n_workers=4, threads_per_worker=1, memory_limit='16GB')
client = Client(cluster)
data_loader = Data_Loader()
#rufe replace_columns_with_preprocessed_fast() auf und übergebe als Parameter alle Ausprägungen der Spaltenklasse
#data_loader.replace_columns_with_preprocessed_fast([spalte for spalte in Spalten])

# %%
#Rufe replace_columns_with_preprocessed_fast() auf und übergebe als Parameter alle Ausprägungen der Spaltenklasse
#data_loader.replace_columns_with_preprocessed_fast([Spalten.AGE, Spalten.FNLWGT, Spalten.HOURS_PER_WEEK, Spalten.CAPITAL_GAIN, Spalten.CAPITAL_LOSS, Spalten.NATIVE_COUNTRY, Spalten.WORKCLASS, Spalten.MARITAL_STATUS, Spalten.OCCUPATION, Spalten.SEX, Spalten.RACE, Spalten.RELATIONSHIP])
data_loader.replace_columns_with_preprocessed_fast([Spalten.EDUCATION])
data_train, data_test = data_loader.get_data()
# Out:
# Merged 1/1 columns.
# C:\Users\aboettinger\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\distributed\client.py:3245: UserWarning: Sending large graph of size 15.96 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# Size of data_train: 0.04877575859427452 GB
# Index(['record_id', 'age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')
# Index(['record_id', 'age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
X_train = data_train.drop(columns=["income"])
Y_train = data_train["income"]
X_test = data_test.drop(columns=["income"])
#Nur die Spalten record_id und income werden benötigt
y_test_with_record_ids = data_test[["record_id", "income"]]
modell_auswertung = Modellauswertung_Dask(X_train, X_test, Y_train, y_test_with_record_ids, client)

# %%
#train_model() wird aufgerufen und die Ergebnisse in variablen gespeichert
accuracy, f1_score_0, f1_score_1 = modell_auswertung.train_model(X_train, X_test)
# Out:
# Windows is not officially supported for dask/xgboost, contribution are welcomed.
# Windows is not officially supported for dask/xgboost, contribution are welcomed.
# C:\Users\aboettinger\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\distributed\client.py:3245: UserWarning: Sending large graph of size 17.05 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# C:\Users\aboettinger\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\distributed\client.py:3245: UserWarning: Sending large graph of size 17.01 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# ...

# %%
client.close()

# %%
print("Accuracy: ", accuracy)
print("F1 Score 0: ", f1_score_0)
print("F1 Score 1: ", f1_score_1)
# Out:
# Accuracy:  0.8706467661691543
# F1 Score 0:  0.9167615253272624
# F1 Score 1:  0.7099652949925632

# %%
ddf.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 ddf.info()
#
# NameError: name 'ddf' is not defined

# %%
ddf.describe(include='all')
# Out:
# Dask DataFrame Structure:
#               record_id      age workclass   fnlwgt education education-num marital-status occupation relationship    race     sex capital-gain capital-loss hours-per-week native-country   income
# npartitions=1
#                 float64  float64    object  float64    object       float64         object     object       object  object  object      float64      float64        float64         object  float64
#                     ...      ...       ...      ...       ...           ...            ...        ...          ...     ...     ...          ...          ...            ...            ...      ...
# Dask Name: concat, 40 expressions
# ...

# %%
import dask.dataframe as dd
from dask.distributed import Client
from dask_ml.model_selection import train_test_split
from xgboost.dask import DaskXGBClassifier, DaskDMatrix

CATEGORICAL_COLUMNS = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country']
# Starte den Dask-Client
client = Client()

# Beispiel-Daten erstellen
import pandas as pd
import numpy as np
# df = pd.DataFrame({
#     'feature1': np.random.rand(100),
#     'feature2': np.random.rand(100),
#     'target': np.random.randint(0, 2, 100)
# })
df = pd.read_csv("dataset/adult_train.csv")
ddf = dd.from_pandas(df, npartitions=2)

# Definiere Feature-Matrix und Zielvariable
#X = ddf.drop('target', axis=1)
#y = ddf['target']
for column in CATEGORICAL_COLUMNS:
    ddf[column] = ddf[column].astype('category')

X = ddf.drop(columns=["income"])
y = ddf["income"]

# Splitte die Daten in Trainings- und Testset
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Initialisiere und trainiere das Modell
clf = DaskXGBClassifier(n_estimators=40, max_depth=5, enable_categorical=True)
clf.client = client
clf.fit(X_train, Y_train)
# Out:
# C:\Users\aboettinger\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\distributed\node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 53267 instead
#   warnings.warn(
# Windows is not officially supported for dask/xgboost, contribution are welcomed.
# Windows is not officially supported for dask/xgboost, contribution are welcomed.
# 2024-07-15 14:22:01,243 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 6341c45d9d51b28c18ea9c4552f118ab initialized by task ('shuffle-transfer-6341c45d9d51b28c18ea9c4552f118ab', 0) executed on worker tcp://127.0.0.1:53290
# 2024-07-15 14:22:02,800 - distributed.shuffle._scheduler_plugin - WARNING - Shuffle 6341c45d9d51b28c18ea9c4552f118ab deactivated due to stimulus 'task-finished-1721046122.7967167'
# DaskXGBClassifier(enable_categorical=True, max_depth=5, n_estimators=40,
# ...

# %%
ddf.info()
# Out:
# <class 'dask_expr.DataFrame'>
# Columns: 16 entries, record_id to income
# dtypes: category(8), int64(8)

# %%
from python_files.ResultsIOHandler import ResultsIOHandler, compare_results_in_table
from python_files.Vorverarbeitung import Preparing_Method
from python_files.Szenario import Szenario

# %%
results_weighted_spec_szenario1 = ResultsIOHandler(Preparing_Method.weighted_specialization, Szenario.szenario1)
results_weighted_spec_szenario2 = ResultsIOHandler(Preparing_Method.weighted_specialization, Szenario.szenario1)
results_forced_generalization_szenario1 = ResultsIOHandler(Preparing_Method.forced_generalization, Szenario.szenario1)
results_forced_generalization_szenario2 = ResultsIOHandler(Preparing_Method.forced_generalization, Szenario.szenario2)
results_spec_szenario1 = ResultsIOHandler(Preparing_Method.specialization, Szenario.szenario1)
results_spec_szenario2 = ResultsIOHandler(Preparing_Method.specialization, Szenario.szenario2)
results_weighted_spec_maximum_confidence = ResultsIOHandler(Preparing_Method.weighted_specialization_highest_confidence, Szenario.szenario2)
results_noPreprocessing_szenario1 = ResultsIOHandler(Preparing_Method.no_preprocessing, Szenario.szenario1)
results_noPreprocessing_szenario2 = ResultsIOHandler(Preparing_Method.no_preprocessing, Szenario.szenario2)
results_extended_specialization_szenario1 = ResultsIOHandler(Preparing_Method.extended_weighted_specialization, Szenario.szenario1)
results_extended_specialization_szenario2 = ResultsIOHandler(Preparing_Method.extended_weighted_specialization, Szenario.szenario2)
results_complete_weighted_specialization_szenario1 = ResultsIOHandler(Preparing_Method.complete_weighted_specialization, Szenario.szenario1)
results_complete_weighted_specialization_szenario2 = ResultsIOHandler(Preparing_Method.complete_weighted_specialization, Szenario.szenario2)
results_complete_forced_generalization_szenario1 = ResultsIOHandler(Preparing_Method.complete_forced_generalization, Szenario.szenario1)
results_complete_forced_generalization_szenario2 = ResultsIOHandler(Preparing_Method.complete_forced_generalization, Szenario.szenario2)
results_complete_noPreprocessing_szenario1 = ResultsIOHandler(Preparing_Method.complete_no_preprocessing, Szenario.szenario1)
results_complete_noPreprocessing_szenario2 = ResultsIOHandler(Preparing_Method.complete_no_preprocessing, Szenario.szenario2)
all_handlers = [results_weighted_spec_szenario1, results_weighted_spec_szenario2, results_spec_szenario1, results_spec_szenario2, results_forced_generalization_szenario1, results_forced_generalization_szenario2, 
                results_weighted_spec_maximum_confidence, results_noPreprocessing_szenario1, results_noPreprocessing_szenario2, results_extended_specialization_szenario1, results_extended_specialization_szenario2,
                results_complete_forced_generalization_szenario1, results_complete_forced_generalization_szenario2, results_complete_noPreprocessing_szenario1, results_complete_noPreprocessing_szenario2, results_complete_weighted_specialization_szenario1, results_complete_weighted_specialization_szenario2]
compare_results_in_table(all_handlers)
compare_results_in_table(all_handlers, True)

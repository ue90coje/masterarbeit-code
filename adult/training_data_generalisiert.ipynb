# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from python_files.Vorverarbeitung import Vorverarbeitung, Spalten

# %%
data_train= pd.read_csv('dataset/manipuliert/adult_train.csv')
data_test= pd.read_csv('dataset/adult_test.csv')
data_original = pd.read_csv('dataset/adult.csv')

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36177 entries, 0 to 36176
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             36177 non-null  object
#  1   workclass       36177 non-null  object
#  2   fnlwgt          36177 non-null  int64
#  3   education       36177 non-null  object
#  4   education-num   36177 non-null  int64
#  5   marital-status  36177 non-null  object
#  6   occupation      36177 non-null  object
#  7   relationship    36177 non-null  object
#  8   race            36177 non-null  object
#  9   sex             36177 non-null  object
#  10  capital-gain    36177 non-null  int64
#  11  capital-loss    36177 non-null  int64
#  12  hours-per-week  36177 non-null  int64
#  13  native-country  36177 non-null  object
#  14  income          36177 non-null  int64
# dtypes: int64(6), object(9)
# memory usage: 4.1+ MB

# %%
import matplotlib.pyplot as plt 
data_original.hist(bins=50,figsize=(20,15))
plt.show()

# %%
vorverarbeitung = Vorverarbeitung(data_train)
#rufe ersetze_durch_mittelwert auf und übergebe eine liste bestehend aus einem Element Spalten.AGE
vorverarbeitung.ersetze_durch_mittelwert([Spalten.AGE])
#vorverarbeitung.erstelle_neue_zeilen([Spalten.SEX, Spalten.RACE, Spalten.NATIVE_COUNTRY])
vorverarbeitung.erstelle_neue_zeilen_v2([Spalten.NATIVE_COUNTRY, Spalten.RACE, Spalten.SEX])
#vorverarbeitung.erstelle_neue_zeilen([Spalten.AGE])
data_train, weights = vorverarbeitung.get_data_and_weights()
# Out:
# Spalte 1/3 | Zeile 1/21774 | erstellt: 17 | Dauer: 0s
# Spalte 1/3 | Zeile 1001/21774 | erstellt: 28354 | Dauer: 0s
# Spalte 1/3 | Zeile 2001/21774 | erstellt: 56697 | Dauer: 0s
# Spalte 1/3 | Zeile 3001/21774 | erstellt: 85861 | Dauer: 0s
# Spalte 1/3 | Zeile 4001/21774 | erstellt: 114935 | Dauer: 0s
# Spalte 1/3 | Zeile 5001/21774 | erstellt: 143875 | Dauer: 0s
# Spalte 1/3 | Zeile 6001/21774 | erstellt: 172783 | Dauer: 0s
# Spalte 1/3 | Zeile 7001/21774 | erstellt: 201805 | Dauer: 0s
# Spalte 1/3 | Zeile 8001/21774 | erstellt: 231049 | Dauer: 1s
# Spalte 1/3 | Zeile 9001/21774 | erstellt: 258981 | Dauer: 0s
# Spalte 1/3 | Zeile 10001/21774 | erstellt: 287535 | Dauer: 0s
# Spalte 1/3 | Zeile 11001/21774 | erstellt: 316114 | Dauer: 1s
# Spalte 1/3 | Zeile 12001/21774 | erstellt: 344865 | Dauer: 0s
# Spalte 1/3 | Zeile 13001/21774 | erstellt: 374145 | Dauer: 1s
# Spalte 1/3 | Zeile 14001/21774 | erstellt: 402329 | Dauer: 0s
# Spalte 1/3 | Zeile 15001/21774 | erstellt: 430915 | Dauer: 0s
# Spalte 1/3 | Zeile 16001/21774 | erstellt: 459389 | Dauer: 0s
# Spalte 1/3 | Zeile 17001/21774 | erstellt: 488326 | Dauer: 1s
# Spalte 1/3 | Zeile 18001/21774 | erstellt: 517388 | Dauer: 0s
# Spalte 1/3 | Zeile 19001/21774 | erstellt: 546800 | Dauer: 0s
# Spalte 1/3 | Zeile 20001/21774 | erstellt: 575924 | Dauer: 0s
# Spalte 1/3 | Zeile 21001/21774 | erstellt: 605094 | Dauer: 1s
# Spalte 2/3 | Zeile 1/321576 | erstellt: 5 | Dauer: 0s
# Spalte 2/3 | Zeile 1001/321576 | erstellt: 5005 | Dauer: 0s
# Spalte 2/3 | Zeile 2001/321576 | erstellt: 10005 | Dauer: 0s
# Spalte 2/3 | Zeile 3001/321576 | erstellt: 15005 | Dauer: 0s
# Spalte 2/3 | Zeile 4001/321576 | erstellt: 20005 | Dauer: 0s
# Spalte 2/3 | Zeile 5001/321576 | erstellt: 25005 | Dauer: 0s
# Spalte 2/3 | Zeile 6001/321576 | erstellt: 30005 | Dauer: 0s
# Spalte 2/3 | Zeile 7001/321576 | erstellt: 35005 | Dauer: 0s
# Spalte 2/3 | Zeile 8001/321576 | erstellt: 40005 | Dauer: 0s
# Spalte 2/3 | Zeile 9001/321576 | erstellt: 45005 | Dauer: 0s
# Spalte 2/3 | Zeile 10001/321576 | erstellt: 50005 | Dauer: 0s
# Spalte 2/3 | Zeile 11001/321576 | erstellt: 55005 | Dauer: 0s
# Spalte 2/3 | Zeile 12001/321576 | erstellt: 60005 | Dauer: 0s
# Spalte 2/3 | Zeile 13001/321576 | erstellt: 65005 | Dauer: 0s
# Spalte 2/3 | Zeile 14001/321576 | erstellt: 70005 | Dauer: 0s
# Spalte 2/3 | Zeile 15001/321576 | erstellt: 75005 | Dauer: 0s
# Spalte 2/3 | Zeile 16001/321576 | erstellt: 80005 | Dauer: 0s
# Spalte 2/3 | Zeile 17001/321576 | erstellt: 85005 | Dauer: 0s
# Spalte 2/3 | Zeile 18001/321576 | erstellt: 90005 | Dauer: 0s
# Spalte 2/3 | Zeile 19001/321576 | erstellt: 95005 | Dauer: 0s
# Spalte 2/3 | Zeile 20001/321576 | erstellt: 100005 | Dauer: 0s
# Spalte 2/3 | Zeile 21001/321576 | erstellt: 105005 | Dauer: 0s
# Spalte 2/3 | Zeile 22001/321576 | erstellt: 110005 | Dauer: 0s
# Spalte 2/3 | Zeile 23001/321576 | erstellt: 115005 | Dauer: 0s
# Spalte 2/3 | Zeile 24001/321576 | erstellt: 120005 | Dauer: 0s
# Spalte 2/3 | Zeile 25001/321576 | erstellt: 125005 | Dauer: 0s
# Spalte 2/3 | Zeile 26001/321576 | erstellt: 130005 | Dauer: 0s
# Spalte 2/3 | Zeile 27001/321576 | erstellt: 135005 | Dauer: 0s
# Spalte 2/3 | Zeile 28001/321576 | erstellt: 140005 | Dauer: 0s
# Spalte 2/3 | Zeile 29001/321576 | erstellt: 145005 | Dauer: 0s
# Spalte 2/3 | Zeile 30001/321576 | erstellt: 150005 | Dauer: 0s
# Spalte 2/3 | Zeile 31001/321576 | erstellt: 155005 | Dauer: 0s
# Spalte 2/3 | Zeile 32001/321576 | erstellt: 160005 | Dauer: 0s
# Spalte 2/3 | Zeile 33001/321576 | erstellt: 165005 | Dauer: 0s
# Spalte 2/3 | Zeile 34001/321576 | erstellt: 170005 | Dauer: 0s
# Spalte 2/3 | Zeile 35001/321576 | erstellt: 175005 | Dauer: 0s
# Spalte 2/3 | Zeile 36001/321576 | erstellt: 180005 | Dauer: 0s
# Spalte 2/3 | Zeile 37001/321576 | erstellt: 185005 | Dauer: 0s
# Spalte 2/3 | Zeile 38001/321576 | erstellt: 190005 | Dauer: 0s
# Spalte 2/3 | Zeile 39001/321576 | erstellt: 195005 | Dauer: 0s
# Spalte 2/3 | Zeile 40001/321576 | erstellt: 200005 | Dauer: 0s
# Spalte 2/3 | Zeile 41001/321576 | erstellt: 205005 | Dauer: 0s
# Spalte 2/3 | Zeile 42001/321576 | erstellt: 210005 | Dauer: 0s
# Spalte 2/3 | Zeile 43001/321576 | erstellt: 215005 | Dauer: 0s
# Spalte 2/3 | Zeile 44001/321576 | erstellt: 220005 | Dauer: 0s
# Spalte 2/3 | Zeile 45001/321576 | erstellt: 225005 | Dauer: 0s
# Spalte 2/3 | Zeile 46001/321576 | erstellt: 230005 | Dauer: 0s
# Spalte 2/3 | Zeile 47001/321576 | erstellt: 235005 | Dauer: 0s
# Spalte 2/3 | Zeile 48001/321576 | erstellt: 240005 | Dauer: 0s
# Spalte 2/3 | Zeile 49001/321576 | erstellt: 245005 | Dauer: 0s
# Spalte 2/3 | Zeile 50001/321576 | erstellt: 250005 | Dauer: 0s
# Spalte 2/3 | Zeile 51001/321576 | erstellt: 255005 | Dauer: 0s
# Spalte 2/3 | Zeile 52001/321576 | erstellt: 260005 | Dauer: 0s
# Spalte 2/3 | Zeile 53001/321576 | erstellt: 265005 | Dauer: 0s
# Spalte 2/3 | Zeile 54001/321576 | erstellt: 270005 | Dauer: 0s
# Spalte 2/3 | Zeile 55001/321576 | erstellt: 275005 | Dauer: 0s
# Spalte 2/3 | Zeile 56001/321576 | erstellt: 280005 | Dauer: 0s
# Spalte 2/3 | Zeile 57001/321576 | erstellt: 285005 | Dauer: 0s
# Spalte 2/3 | Zeile 58001/321576 | erstellt: 290005 | Dauer: 0s
# Spalte 2/3 | Zeile 59001/321576 | erstellt: 295005 | Dauer: 0s
# Spalte 2/3 | Zeile 60001/321576 | erstellt: 300005 | Dauer: 0s
# Spalte 2/3 | Zeile 61001/321576 | erstellt: 305005 | Dauer: 0s
# Spalte 2/3 | Zeile 62001/321576 | erstellt: 310005 | Dauer: 0s
# Spalte 2/3 | Zeile 63001/321576 | erstellt: 315005 | Dauer: 0s
# Spalte 2/3 | Zeile 64001/321576 | erstellt: 320005 | Dauer: 0s
# Spalte 2/3 | Zeile 65001/321576 | erstellt: 325005 | Dauer: 0s
# Spalte 2/3 | Zeile 66001/321576 | erstellt: 330005 | Dauer: 0s
# Spalte 2/3 | Zeile 67001/321576 | erstellt: 335005 | Dauer: 0s
# Spalte 2/3 | Zeile 68001/321576 | erstellt: 340005 | Dauer: 0s
# Spalte 2/3 | Zeile 69001/321576 | erstellt: 345005 | Dauer: 0s
# Spalte 2/3 | Zeile 70001/321576 | erstellt: 350005 | Dauer: 0s
# Spalte 2/3 | Zeile 71001/321576 | erstellt: 355005 | Dauer: 0s
# Spalte 2/3 | Zeile 72001/321576 | erstellt: 360005 | Dauer: 0s
# Spalte 2/3 | Zeile 73001/321576 | erstellt: 365005 | Dauer: 0s
# Spalte 2/3 | Zeile 74001/321576 | erstellt: 370005 | Dauer: 0s
# Spalte 2/3 | Zeile 75001/321576 | erstellt: 375005 | Dauer: 0s
# Spalte 2/3 | Zeile 76001/321576 | erstellt: 380005 | Dauer: 0s
# Spalte 2/3 | Zeile 77001/321576 | erstellt: 385005 | Dauer: 0s
# Spalte 2/3 | Zeile 78001/321576 | erstellt: 390005 | Dauer: 0s
# Spalte 2/3 | Zeile 79001/321576 | erstellt: 395005 | Dauer: 0s
# Spalte 2/3 | Zeile 80001/321576 | erstellt: 400005 | Dauer: 0s
# Spalte 2/3 | Zeile 81001/321576 | erstellt: 405005 | Dauer: 0s
# Spalte 2/3 | Zeile 82001/321576 | erstellt: 410005 | Dauer: 0s
# Spalte 2/3 | Zeile 83001/321576 | erstellt: 415005 | Dauer: 0s
# Spalte 2/3 | Zeile 84001/321576 | erstellt: 420005 | Dauer: 0s
# Spalte 2/3 | Zeile 85001/321576 | erstellt: 425005 | Dauer: 0s
# Spalte 2/3 | Zeile 86001/321576 | erstellt: 430005 | Dauer: 0s
# Spalte 2/3 | Zeile 87001/321576 | erstellt: 435005 | Dauer: 0s
# Spalte 2/3 | Zeile 88001/321576 | erstellt: 440005 | Dauer: 0s
# Spalte 2/3 | Zeile 89001/321576 | erstellt: 445005 | Dauer: 0s
# Spalte 2/3 | Zeile 90001/321576 | erstellt: 450005 | Dauer: 0s
# Spalte 2/3 | Zeile 91001/321576 | erstellt: 455005 | Dauer: 1s
# Spalte 2/3 | Zeile 92001/321576 | erstellt: 460005 | Dauer: 0s
# Spalte 2/3 | Zeile 93001/321576 | erstellt: 465005 | Dauer: 0s
# Spalte 2/3 | Zeile 94001/321576 | erstellt: 470005 | Dauer: 0s
# Spalte 2/3 | Zeile 95001/321576 | erstellt: 475005 | Dauer: 0s
# Spalte 2/3 | Zeile 96001/321576 | erstellt: 480005 | Dauer: 0s
# Spalte 2/3 | Zeile 97001/321576 | erstellt: 485005 | Dauer: 0s
# Spalte 2/3 | Zeile 98001/321576 | erstellt: 490005 | Dauer: 0s
# Spalte 2/3 | Zeile 99001/321576 | erstellt: 495005 | Dauer: 0s
# Spalte 2/3 | Zeile 100001/321576 | erstellt: 500005 | Dauer: 0s
# Spalte 2/3 | Zeile 101001/321576 | erstellt: 505005 | Dauer: 0s
# Spalte 2/3 | Zeile 102001/321576 | erstellt: 510005 | Dauer: 0s
# Spalte 2/3 | Zeile 103001/321576 | erstellt: 515005 | Dauer: 0s
# Spalte 2/3 | Zeile 104001/321576 | erstellt: 520005 | Dauer: 0s
# Spalte 2/3 | Zeile 105001/321576 | erstellt: 525005 | Dauer: 0s
# Spalte 2/3 | Zeile 106001/321576 | erstellt: 530005 | Dauer: 0s
# Spalte 2/3 | Zeile 107001/321576 | erstellt: 535005 | Dauer: 0s
# Spalte 2/3 | Zeile 108001/321576 | erstellt: 540005 | Dauer: 0s
# Spalte 2/3 | Zeile 109001/321576 | erstellt: 545005 | Dauer: 0s
# Spalte 2/3 | Zeile 110001/321576 | erstellt: 550005 | Dauer: 0s
# Spalte 2/3 | Zeile 111001/321576 | erstellt: 555005 | Dauer: 0s
# Spalte 2/3 | Zeile 112001/321576 | erstellt: 560005 | Dauer: 0s
# Spalte 2/3 | Zeile 113001/321576 | erstellt: 565005 | Dauer: 0s
# Spalte 2/3 | Zeile 114001/321576 | erstellt: 570005 | Dauer: 0s
# Spalte 2/3 | Zeile 115001/321576 | erstellt: 575005 | Dauer: 1s
# Spalte 2/3 | Zeile 116001/321576 | erstellt: 580005 | Dauer: 0s
# Spalte 2/3 | Zeile 117001/321576 | erstellt: 585005 | Dauer: 0s
# Spalte 2/3 | Zeile 118001/321576 | erstellt: 590005 | Dauer: 0s
# Spalte 2/3 | Zeile 119001/321576 | erstellt: 595005 | Dauer: 0s
# Spalte 2/3 | Zeile 120001/321576 | erstellt: 600005 | Dauer: 0s
# Spalte 2/3 | Zeile 121001/321576 | erstellt: 605005 | Dauer: 0s
# Spalte 2/3 | Zeile 122001/321576 | erstellt: 610005 | Dauer: 0s
# Spalte 2/3 | Zeile 123001/321576 | erstellt: 615005 | Dauer: 0s
# Spalte 2/3 | Zeile 124001/321576 | erstellt: 620005 | Dauer: 0s
# Spalte 2/3 | Zeile 125001/321576 | erstellt: 625005 | Dauer: 0s
# Spalte 2/3 | Zeile 126001/321576 | erstellt: 630005 | Dauer: 0s
# Spalte 2/3 | Zeile 127001/321576 | erstellt: 635005 | Dauer: 0s
# Spalte 2/3 | Zeile 128001/321576 | erstellt: 640005 | Dauer: 0s
# Spalte 2/3 | Zeile 129001/321576 | erstellt: 645005 | Dauer: 0s
# Spalte 2/3 | Zeile 130001/321576 | erstellt: 650005 | Dauer: 0s
# Spalte 2/3 | Zeile 131001/321576 | erstellt: 655005 | Dauer: 0s
# Spalte 2/3 | Zeile 132001/321576 | erstellt: 660005 | Dauer: 0s
# Spalte 2/3 | Zeile 133001/321576 | erstellt: 665005 | Dauer: 0s
# Spalte 2/3 | Zeile 134001/321576 | erstellt: 670005 | Dauer: 0s
# Spalte 2/3 | Zeile 135001/321576 | erstellt: 675005 | Dauer: 0s
# Spalte 2/3 | Zeile 136001/321576 | erstellt: 680005 | Dauer: 0s
# Spalte 2/3 | Zeile 137001/321576 | erstellt: 685005 | Dauer: 0s
# Spalte 2/3 | Zeile 138001/321576 | erstellt: 690005 | Dauer: 0s
# Spalte 2/3 | Zeile 139001/321576 | erstellt: 695005 | Dauer: 0s
# Spalte 2/3 | Zeile 140001/321576 | erstellt: 700005 | Dauer: 0s
# Spalte 2/3 | Zeile 141001/321576 | erstellt: 705005 | Dauer: 0s
# Spalte 2/3 | Zeile 142001/321576 | erstellt: 710005 | Dauer: 0s
# Spalte 2/3 | Zeile 143001/321576 | erstellt: 715005 | Dauer: 0s
# Spalte 2/3 | Zeile 144001/321576 | erstellt: 720005 | Dauer: 1s
# Spalte 2/3 | Zeile 145001/321576 | erstellt: 725005 | Dauer: 0s
# Spalte 2/3 | Zeile 146001/321576 | erstellt: 730005 | Dauer: 0s
# Spalte 2/3 | Zeile 147001/321576 | erstellt: 735005 | Dauer: 0s
# Spalte 2/3 | Zeile 148001/321576 | erstellt: 740005 | Dauer: 0s
# Spalte 2/3 | Zeile 149001/321576 | erstellt: 745005 | Dauer: 0s
# Spalte 2/3 | Zeile 150001/321576 | erstellt: 750005 | Dauer: 0s
# Spalte 2/3 | Zeile 151001/321576 | erstellt: 755005 | Dauer: 0s
# Spalte 2/3 | Zeile 152001/321576 | erstellt: 760005 | Dauer: 0s
# Spalte 2/3 | Zeile 153001/321576 | erstellt: 765005 | Dauer: 0s
# Spalte 2/3 | Zeile 154001/321576 | erstellt: 770005 | Dauer: 0s
# Spalte 2/3 | Zeile 155001/321576 | erstellt: 775005 | Dauer: 0s
# Spalte 2/3 | Zeile 156001/321576 | erstellt: 780005 | Dauer: 0s
# Spalte 2/3 | Zeile 157001/321576 | erstellt: 785005 | Dauer: 0s
# Spalte 2/3 | Zeile 158001/321576 | erstellt: 790005 | Dauer: 0s
# Spalte 2/3 | Zeile 159001/321576 | erstellt: 795005 | Dauer: 0s
# Spalte 2/3 | Zeile 160001/321576 | erstellt: 800005 | Dauer: 0s
# Spalte 2/3 | Zeile 161001/321576 | erstellt: 805005 | Dauer: 0s
# Spalte 2/3 | Zeile 162001/321576 | erstellt: 810005 | Dauer: 0s
# Spalte 2/3 | Zeile 163001/321576 | erstellt: 815005 | Dauer: 0s
# Spalte 2/3 | Zeile 164001/321576 | erstellt: 820005 | Dauer: 0s
# Spalte 2/3 | Zeile 165001/321576 | erstellt: 825005 | Dauer: 0s
# Spalte 2/3 | Zeile 166001/321576 | erstellt: 830005 | Dauer: 0s
# Spalte 2/3 | Zeile 167001/321576 | erstellt: 835005 | Dauer: 0s
# Spalte 2/3 | Zeile 168001/321576 | erstellt: 840005 | Dauer: 0s
# Spalte 2/3 | Zeile 169001/321576 | erstellt: 845005 | Dauer: 0s
# Spalte 2/3 | Zeile 170001/321576 | erstellt: 850005 | Dauer: 0s
# Spalte 2/3 | Zeile 171001/321576 | erstellt: 855005 | Dauer: 0s
# Spalte 2/3 | Zeile 172001/321576 | erstellt: 860005 | Dauer: 0s
# Spalte 2/3 | Zeile 173001/321576 | erstellt: 865005 | Dauer: 0s
# Spalte 2/3 | Zeile 174001/321576 | erstellt: 870005 | Dauer: 0s
# Spalte 2/3 | Zeile 175001/321576 | erstellt: 875005 | Dauer: 0s
# Spalte 2/3 | Zeile 176001/321576 | erstellt: 880005 | Dauer: 0s
# Spalte 2/3 | Zeile 177001/321576 | erstellt: 885005 | Dauer: 0s
# Spalte 2/3 | Zeile 178001/321576 | erstellt: 890005 | Dauer: 0s
# Spalte 2/3 | Zeile 179001/321576 | erstellt: 895005 | Dauer: 0s
# Spalte 2/3 | Zeile 180001/321576 | erstellt: 900005 | Dauer: 0s
# Spalte 2/3 | Zeile 181001/321576 | erstellt: 905005 | Dauer: 2s
# Spalte 2/3 | Zeile 182001/321576 | erstellt: 910005 | Dauer: 0s
# Spalte 2/3 | Zeile 183001/321576 | erstellt: 915005 | Dauer: 0s
# Spalte 2/3 | Zeile 184001/321576 | erstellt: 920005 | Dauer: 0s
# Spalte 2/3 | Zeile 185001/321576 | erstellt: 925005 | Dauer: 0s
# Spalte 2/3 | Zeile 186001/321576 | erstellt: 930005 | Dauer: 0s
# Spalte 2/3 | Zeile 187001/321576 | erstellt: 935005 | Dauer: 0s
# Spalte 2/3 | Zeile 188001/321576 | erstellt: 940005 | Dauer: 0s
# Spalte 2/3 | Zeile 189001/321576 | erstellt: 945005 | Dauer: 0s
# Spalte 2/3 | Zeile 190001/321576 | erstellt: 950005 | Dauer: 0s
# Spalte 2/3 | Zeile 191001/321576 | erstellt: 955005 | Dauer: 0s
# Spalte 2/3 | Zeile 192001/321576 | erstellt: 960005 | Dauer: 0s
# Spalte 2/3 | Zeile 193001/321576 | erstellt: 965005 | Dauer: 0s
# Spalte 2/3 | Zeile 194001/321576 | erstellt: 970005 | Dauer: 0s
# Spalte 2/3 | Zeile 195001/321576 | erstellt: 975005 | Dauer: 0s
# Spalte 2/3 | Zeile 196001/321576 | erstellt: 980005 | Dauer: 0s
# Spalte 2/3 | Zeile 197001/321576 | erstellt: 985005 | Dauer: 0s
# Spalte 2/3 | Zeile 198001/321576 | erstellt: 990005 | Dauer: 0s
# Spalte 2/3 | Zeile 199001/321576 | erstellt: 995005 | Dauer: 0s
# Spalte 2/3 | Zeile 200001/321576 | erstellt: 1000005 | Dauer: 0s
# Spalte 2/3 | Zeile 201001/321576 | erstellt: 1005005 | Dauer: 0s
# Spalte 2/3 | Zeile 202001/321576 | erstellt: 1010005 | Dauer: 0s
# Spalte 2/3 | Zeile 203001/321576 | erstellt: 1015005 | Dauer: 0s
# Spalte 2/3 | Zeile 204001/321576 | erstellt: 1020005 | Dauer: 0s
# Spalte 2/3 | Zeile 205001/321576 | erstellt: 1025005 | Dauer: 0s
# Spalte 2/3 | Zeile 206001/321576 | erstellt: 1030005 | Dauer: 0s
# Spalte 2/3 | Zeile 207001/321576 | erstellt: 1035005 | Dauer: 0s
# Spalte 2/3 | Zeile 208001/321576 | erstellt: 1040005 | Dauer: 0s
# Spalte 2/3 | Zeile 209001/321576 | erstellt: 1045005 | Dauer: 0s
# Spalte 2/3 | Zeile 210001/321576 | erstellt: 1050005 | Dauer: 0s
# Spalte 2/3 | Zeile 211001/321576 | erstellt: 1055005 | Dauer: 0s
# Spalte 2/3 | Zeile 212001/321576 | erstellt: 1060005 | Dauer: 0s
# Spalte 2/3 | Zeile 213001/321576 | erstellt: 1065005 | Dauer: 0s
# Spalte 2/3 | Zeile 214001/321576 | erstellt: 1070005 | Dauer: 0s
# Spalte 2/3 | Zeile 215001/321576 | erstellt: 1075005 | Dauer: 0s
# Spalte 2/3 | Zeile 216001/321576 | erstellt: 1080005 | Dauer: 0s
# Spalte 2/3 | Zeile 217001/321576 | erstellt: 1085005 | Dauer: 0s
# Spalte 2/3 | Zeile 218001/321576 | erstellt: 1090005 | Dauer: 0s
# Spalte 2/3 | Zeile 219001/321576 | erstellt: 1095005 | Dauer: 0s
# Spalte 2/3 | Zeile 220001/321576 | erstellt: 1100005 | Dauer: 0s
# Spalte 2/3 | Zeile 221001/321576 | erstellt: 1105005 | Dauer: 0s
# Spalte 2/3 | Zeile 222001/321576 | erstellt: 1110005 | Dauer: 0s
# Spalte 2/3 | Zeile 223001/321576 | erstellt: 1115005 | Dauer: 0s
# Spalte 2/3 | Zeile 224001/321576 | erstellt: 1120005 | Dauer: 0s
# Spalte 2/3 | Zeile 225001/321576 | erstellt: 1125005 | Dauer: 0s
# Spalte 2/3 | Zeile 226001/321576 | erstellt: 1130005 | Dauer: 0s
# Spalte 2/3 | Zeile 227001/321576 | erstellt: 1135005 | Dauer: 2s
# Spalte 2/3 | Zeile 228001/321576 | erstellt: 1140005 | Dauer: 0s
# Spalte 2/3 | Zeile 229001/321576 | erstellt: 1145005 | Dauer: 0s
# Spalte 2/3 | Zeile 230001/321576 | erstellt: 1150005 | Dauer: 0s
# Spalte 2/3 | Zeile 231001/321576 | erstellt: 1155005 | Dauer: 0s
# Spalte 2/3 | Zeile 232001/321576 | erstellt: 1160005 | Dauer: 0s
# Spalte 2/3 | Zeile 233001/321576 | erstellt: 1165005 | Dauer: 0s
# Spalte 2/3 | Zeile 234001/321576 | erstellt: 1170005 | Dauer: 0s
# Spalte 2/3 | Zeile 235001/321576 | erstellt: 1175005 | Dauer: 0s
# Spalte 2/3 | Zeile 236001/321576 | erstellt: 1180005 | Dauer: 0s
# Spalte 2/3 | Zeile 237001/321576 | erstellt: 1185005 | Dauer: 0s
# Spalte 2/3 | Zeile 238001/321576 | erstellt: 1190005 | Dauer: 0s
# Spalte 2/3 | Zeile 239001/321576 | erstellt: 1195005 | Dauer: 0s
# Spalte 2/3 | Zeile 240001/321576 | erstellt: 1200005 | Dauer: 0s
# Spalte 2/3 | Zeile 241001/321576 | erstellt: 1205005 | Dauer: 0s
# Spalte 2/3 | Zeile 242001/321576 | erstellt: 1210005 | Dauer: 0s
# Spalte 2/3 | Zeile 243001/321576 | erstellt: 1215005 | Dauer: 0s
# Spalte 2/3 | Zeile 244001/321576 | erstellt: 1220005 | Dauer: 0s
# Spalte 2/3 | Zeile 245001/321576 | erstellt: 1225005 | Dauer: 0s
# Spalte 2/3 | Zeile 246001/321576 | erstellt: 1230005 | Dauer: 0s
# Spalte 2/3 | Zeile 247001/321576 | erstellt: 1235005 | Dauer: 0s
# Spalte 2/3 | Zeile 248001/321576 | erstellt: 1240005 | Dauer: 0s
# Spalte 2/3 | Zeile 249001/321576 | erstellt: 1245005 | Dauer: 0s
# Spalte 2/3 | Zeile 250001/321576 | erstellt: 1250005 | Dauer: 0s
# Spalte 2/3 | Zeile 251001/321576 | erstellt: 1255005 | Dauer: 0s
# Spalte 2/3 | Zeile 252001/321576 | erstellt: 1260005 | Dauer: 0s
# Spalte 2/3 | Zeile 253001/321576 | erstellt: 1265005 | Dauer: 0s
# Spalte 2/3 | Zeile 254001/321576 | erstellt: 1270005 | Dauer: 0s
# Spalte 2/3 | Zeile 255001/321576 | erstellt: 1275005 | Dauer: 0s
# Spalte 2/3 | Zeile 256001/321576 | erstellt: 1280005 | Dauer: 0s
# Spalte 2/3 | Zeile 257001/321576 | erstellt: 1285005 | Dauer: 0s
# Spalte 2/3 | Zeile 258001/321576 | erstellt: 1290005 | Dauer: 0s
# Spalte 2/3 | Zeile 259001/321576 | erstellt: 1295005 | Dauer: 0s
# Spalte 2/3 | Zeile 260001/321576 | erstellt: 1300005 | Dauer: 0s
# Spalte 2/3 | Zeile 261001/321576 | erstellt: 1305005 | Dauer: 0s
# Spalte 2/3 | Zeile 262001/321576 | erstellt: 1310005 | Dauer: 0s
# Spalte 2/3 | Zeile 263001/321576 | erstellt: 1315005 | Dauer: 0s
# Spalte 2/3 | Zeile 264001/321576 | erstellt: 1320005 | Dauer: 0s
# Spalte 2/3 | Zeile 265001/321576 | erstellt: 1325005 | Dauer: 0s
# Spalte 2/3 | Zeile 266001/321576 | erstellt: 1330005 | Dauer: 0s
# Spalte 2/3 | Zeile 267001/321576 | erstellt: 1335005 | Dauer: 0s
# Spalte 2/3 | Zeile 268001/321576 | erstellt: 1340005 | Dauer: 0s
# Spalte 2/3 | Zeile 269001/321576 | erstellt: 1345005 | Dauer: 0s
# Spalte 2/3 | Zeile 270001/321576 | erstellt: 1350005 | Dauer: 0s
# Spalte 2/3 | Zeile 271001/321576 | erstellt: 1355005 | Dauer: 0s
# Spalte 2/3 | Zeile 272001/321576 | erstellt: 1360005 | Dauer: 0s
# Spalte 2/3 | Zeile 273001/321576 | erstellt: 1365005 | Dauer: 0s
# Spalte 2/3 | Zeile 274001/321576 | erstellt: 1370005 | Dauer: 0s
# Spalte 2/3 | Zeile 275001/321576 | erstellt: 1375005 | Dauer: 0s
# Spalte 2/3 | Zeile 276001/321576 | erstellt: 1380005 | Dauer: 0s
# Spalte 2/3 | Zeile 277001/321576 | erstellt: 1385005 | Dauer: 0s
# Spalte 2/3 | Zeile 278001/321576 | erstellt: 1390005 | Dauer: 0s
# Spalte 2/3 | Zeile 279001/321576 | erstellt: 1395005 | Dauer: 0s
# Spalte 2/3 | Zeile 280001/321576 | erstellt: 1400005 | Dauer: 0s
# Spalte 2/3 | Zeile 281001/321576 | erstellt: 1405005 | Dauer: 0s
# Spalte 2/3 | Zeile 282001/321576 | erstellt: 1410005 | Dauer: 0s
# Spalte 2/3 | Zeile 283001/321576 | erstellt: 1415005 | Dauer: 0s
# Spalte 2/3 | Zeile 284001/321576 | erstellt: 1420005 | Dauer: 3s
# Spalte 2/3 | Zeile 285001/321576 | erstellt: 1425005 | Dauer: 0s
# Spalte 2/3 | Zeile 286001/321576 | erstellt: 1430005 | Dauer: 0s
# Spalte 2/3 | Zeile 287001/321576 | erstellt: 1435005 | Dauer: 0s
# Spalte 2/3 | Zeile 288001/321576 | erstellt: 1440005 | Dauer: 0s
# Spalte 2/3 | Zeile 289001/321576 | erstellt: 1445005 | Dauer: 0s
# Spalte 2/3 | Zeile 290001/321576 | erstellt: 1450005 | Dauer: 0s
# Spalte 2/3 | Zeile 291001/321576 | erstellt: 1455005 | Dauer: 0s
# Spalte 2/3 | Zeile 292001/321576 | erstellt: 1460005 | Dauer: 0s
# Spalte 2/3 | Zeile 293001/321576 | erstellt: 1465005 | Dauer: 0s
# Spalte 2/3 | Zeile 294001/321576 | erstellt: 1470005 | Dauer: 0s
# Spalte 2/3 | Zeile 295001/321576 | erstellt: 1475005 | Dauer: 0s
# Spalte 2/3 | Zeile 296001/321576 | erstellt: 1480005 | Dauer: 0s
# Spalte 2/3 | Zeile 297001/321576 | erstellt: 1485005 | Dauer: 0s
# Spalte 2/3 | Zeile 298001/321576 | erstellt: 1490005 | Dauer: 0s
# Spalte 2/3 | Zeile 299001/321576 | erstellt: 1495005 | Dauer: 0s
# Spalte 2/3 | Zeile 300001/321576 | erstellt: 1500005 | Dauer: 0s
# Spalte 2/3 | Zeile 301001/321576 | erstellt: 1505005 | Dauer: 0s
# Spalte 2/3 | Zeile 302001/321576 | erstellt: 1510005 | Dauer: 0s
# Spalte 2/3 | Zeile 303001/321576 | erstellt: 1515005 | Dauer: 0s
# Spalte 2/3 | Zeile 304001/321576 | erstellt: 1520005 | Dauer: 0s
# Spalte 2/3 | Zeile 305001/321576 | erstellt: 1525005 | Dauer: 0s
# Spalte 2/3 | Zeile 306001/321576 | erstellt: 1530005 | Dauer: 0s
# Spalte 2/3 | Zeile 307001/321576 | erstellt: 1535005 | Dauer: 0s
# Spalte 2/3 | Zeile 308001/321576 | erstellt: 1540005 | Dauer: 0s
# Spalte 2/3 | Zeile 309001/321576 | erstellt: 1545005 | Dauer: 0s
# Spalte 2/3 | Zeile 310001/321576 | erstellt: 1550005 | Dauer: 0s
# Spalte 2/3 | Zeile 311001/321576 | erstellt: 1555005 | Dauer: 0s
# Spalte 2/3 | Zeile 312001/321576 | erstellt: 1560005 | Dauer: 0s
# Spalte 2/3 | Zeile 313001/321576 | erstellt: 1565005 | Dauer: 0s
# Spalte 2/3 | Zeile 314001/321576 | erstellt: 1570005 | Dauer: 0s
# Spalte 2/3 | Zeile 315001/321576 | erstellt: 1575005 | Dauer: 0s
# Spalte 2/3 | Zeile 316001/321576 | erstellt: 1580005 | Dauer: 0s
# Spalte 2/3 | Zeile 317001/321576 | erstellt: 1585005 | Dauer: 0s
# Spalte 2/3 | Zeile 318001/321576 | erstellt: 1590005 | Dauer: 0s
# Spalte 2/3 | Zeile 319001/321576 | erstellt: 1595005 | Dauer: 0s
# Spalte 2/3 | Zeile 320001/321576 | erstellt: 1600005 | Dauer: 0s
# Spalte 2/3 | Zeile 321001/321576 | erstellt: 1605005 | Dauer: 0s
# Spalte 3/3 | Zeile 1/964586 | erstellt: 2 | Dauer: 1s
# Spalte 3/3 | Zeile 1001/964586 | erstellt: 2002 | Dauer: 0s
# Spalte 3/3 | Zeile 2001/964586 | erstellt: 4002 | Dauer: 0s
# Spalte 3/3 | Zeile 3001/964586 | erstellt: 6002 | Dauer: 0s
# Spalte 3/3 | Zeile 4001/964586 | erstellt: 8002 | Dauer: 0s
# Spalte 3/3 | Zeile 5001/964586 | erstellt: 10002 | Dauer: 0s
# Spalte 3/3 | Zeile 6001/964586 | erstellt: 12002 | Dauer: 0s
# Spalte 3/3 | Zeile 7001/964586 | erstellt: 14002 | Dauer: 0s
# Spalte 3/3 | Zeile 8001/964586 | erstellt: 16002 | Dauer: 0s
# Spalte 3/3 | Zeile 9001/964586 | erstellt: 18002 | Dauer: 0s
# Spalte 3/3 | Zeile 10001/964586 | erstellt: 20002 | Dauer: 0s
# Spalte 3/3 | Zeile 11001/964586 | erstellt: 22002 | Dauer: 0s
# Spalte 3/3 | Zeile 12001/964586 | erstellt: 24002 | Dauer: 0s
# Spalte 3/3 | Zeile 13001/964586 | erstellt: 26002 | Dauer: 0s
# Spalte 3/3 | Zeile 14001/964586 | erstellt: 28002 | Dauer: 0s
# Spalte 3/3 | Zeile 15001/964586 | erstellt: 30002 | Dauer: 0s
# Spalte 3/3 | Zeile 16001/964586 | erstellt: 32002 | Dauer: 0s
# Spalte 3/3 | Zeile 17001/964586 | erstellt: 34002 | Dauer: 0s
# Spalte 3/3 | Zeile 18001/964586 | erstellt: 36002 | Dauer: 0s
# Spalte 3/3 | Zeile 19001/964586 | erstellt: 38002 | Dauer: 0s
# Spalte 3/3 | Zeile 20001/964586 | erstellt: 40002 | Dauer: 0s
# Spalte 3/3 | Zeile 21001/964586 | erstellt: 42002 | Dauer: 0s
# Spalte 3/3 | Zeile 22001/964586 | erstellt: 44002 | Dauer: 0s
# Spalte 3/3 | Zeile 23001/964586 | erstellt: 46002 | Dauer: 0s
# Spalte 3/3 | Zeile 24001/964586 | erstellt: 48002 | Dauer: 0s
# Spalte 3/3 | Zeile 25001/964586 | erstellt: 50002 | Dauer: 0s
# Spalte 3/3 | Zeile 26001/964586 | erstellt: 52002 | Dauer: 0s
# Spalte 3/3 | Zeile 27001/964586 | erstellt: 54002 | Dauer: 0s
# Spalte 3/3 | Zeile 28001/964586 | erstellt: 56002 | Dauer: 0s
# Spalte 3/3 | Zeile 29001/964586 | erstellt: 58002 | Dauer: 0s
# Spalte 3/3 | Zeile 30001/964586 | erstellt: 60002 | Dauer: 0s
# Spalte 3/3 | Zeile 31001/964586 | erstellt: 62002 | Dauer: 0s
# Spalte 3/3 | Zeile 32001/964586 | erstellt: 64002 | Dauer: 0s
# Spalte 3/3 | Zeile 33001/964586 | erstellt: 66002 | Dauer: 0s
# Spalte 3/3 | Zeile 34001/964586 | erstellt: 68002 | Dauer: 0s
# Spalte 3/3 | Zeile 35001/964586 | erstellt: 70002 | Dauer: 0s
# Spalte 3/3 | Zeile 36001/964586 | erstellt: 72002 | Dauer: 0s
# Spalte 3/3 | Zeile 37001/964586 | erstellt: 74002 | Dauer: 0s
# Spalte 3/3 | Zeile 38001/964586 | erstellt: 76002 | Dauer: 0s
# Spalte 3/3 | Zeile 39001/964586 | erstellt: 78002 | Dauer: 0s
# Spalte 3/3 | Zeile 40001/964586 | erstellt: 80002 | Dauer: 0s
# Spalte 3/3 | Zeile 41001/964586 | erstellt: 82002 | Dauer: 0s
# Spalte 3/3 | Zeile 42001/964586 | erstellt: 84002 | Dauer: 0s
# Spalte 3/3 | Zeile 43001/964586 | erstellt: 86002 | Dauer: 0s
# Spalte 3/3 | Zeile 44001/964586 | erstellt: 88002 | Dauer: 0s
# Spalte 3/3 | Zeile 45001/964586 | erstellt: 90002 | Dauer: 0s
# Spalte 3/3 | Zeile 46001/964586 | erstellt: 92002 | Dauer: 0s
# Spalte 3/3 | Zeile 47001/964586 | erstellt: 94002 | Dauer: 0s
# Spalte 3/3 | Zeile 48001/964586 | erstellt: 96002 | Dauer: 0s
# Spalte 3/3 | Zeile 49001/964586 | erstellt: 98002 | Dauer: 0s
# Spalte 3/3 | Zeile 50001/964586 | erstellt: 100002 | Dauer: 0s
# Spalte 3/3 | Zeile 51001/964586 | erstellt: 102002 | Dauer: 0s
# Spalte 3/3 | Zeile 52001/964586 | erstellt: 104002 | Dauer: 0s
# Spalte 3/3 | Zeile 53001/964586 | erstellt: 106002 | Dauer: 0s
# Spalte 3/3 | Zeile 54001/964586 | erstellt: 108002 | Dauer: 0s
# Spalte 3/3 | Zeile 55001/964586 | erstellt: 110002 | Dauer: 0s
# Spalte 3/3 | Zeile 56001/964586 | erstellt: 112002 | Dauer: 0s
# Spalte 3/3 | Zeile 57001/964586 | erstellt: 114002 | Dauer: 0s
# Spalte 3/3 | Zeile 58001/964586 | erstellt: 116002 | Dauer: 0s
# Spalte 3/3 | Zeile 59001/964586 | erstellt: 118002 | Dauer: 0s
# Spalte 3/3 | Zeile 60001/964586 | erstellt: 120002 | Dauer: 0s
# Spalte 3/3 | Zeile 61001/964586 | erstellt: 122002 | Dauer: 0s
# Spalte 3/3 | Zeile 62001/964586 | erstellt: 124002 | Dauer: 0s
# Spalte 3/3 | Zeile 63001/964586 | erstellt: 126002 | Dauer: 0s
# Spalte 3/3 | Zeile 64001/964586 | erstellt: 128002 | Dauer: 0s
# Spalte 3/3 | Zeile 65001/964586 | erstellt: 130002 | Dauer: 0s
# Spalte 3/3 | Zeile 66001/964586 | erstellt: 132002 | Dauer: 0s
# Spalte 3/3 | Zeile 67001/964586 | erstellt: 134002 | Dauer: 0s
# Spalte 3/3 | Zeile 68001/964586 | erstellt: 136002 | Dauer: 0s
# Spalte 3/3 | Zeile 69001/964586 | erstellt: 138002 | Dauer: 0s
# Spalte 3/3 | Zeile 70001/964586 | erstellt: 140002 | Dauer: 0s
# Spalte 3/3 | Zeile 71001/964586 | erstellt: 142002 | Dauer: 0s
# Spalte 3/3 | Zeile 72001/964586 | erstellt: 144002 | Dauer: 0s
# Spalte 3/3 | Zeile 73001/964586 | erstellt: 146002 | Dauer: 0s
# Spalte 3/3 | Zeile 74001/964586 | erstellt: 148002 | Dauer: 0s
# Spalte 3/3 | Zeile 75001/964586 | erstellt: 150002 | Dauer: 0s
# Spalte 3/3 | Zeile 76001/964586 | erstellt: 152002 | Dauer: 0s
# Spalte 3/3 | Zeile 77001/964586 | erstellt: 154002 | Dauer: 0s
# Spalte 3/3 | Zeile 78001/964586 | erstellt: 156002 | Dauer: 0s
# Spalte 3/3 | Zeile 79001/964586 | erstellt: 158002 | Dauer: 0s
# Spalte 3/3 | Zeile 80001/964586 | erstellt: 160002 | Dauer: 0s
# Spalte 3/3 | Zeile 81001/964586 | erstellt: 162002 | Dauer: 0s
# Spalte 3/3 | Zeile 82001/964586 | erstellt: 164002 | Dauer: 0s
# Spalte 3/3 | Zeile 83001/964586 | erstellt: 166002 | Dauer: 0s
# Spalte 3/3 | Zeile 84001/964586 | erstellt: 168002 | Dauer: 0s
# Spalte 3/3 | Zeile 85001/964586 | erstellt: 170002 | Dauer: 0s
# Spalte 3/3 | Zeile 86001/964586 | erstellt: 172002 | Dauer: 0s
# Spalte 3/3 | Zeile 87001/964586 | erstellt: 174002 | Dauer: 0s
# Spalte 3/3 | Zeile 88001/964586 | erstellt: 176002 | Dauer: 0s
# Spalte 3/3 | Zeile 89001/964586 | erstellt: 178002 | Dauer: 0s
# Spalte 3/3 | Zeile 90001/964586 | erstellt: 180002 | Dauer: 0s
# Spalte 3/3 | Zeile 91001/964586 | erstellt: 182002 | Dauer: 0s
# Spalte 3/3 | Zeile 92001/964586 | erstellt: 184002 | Dauer: 0s
# Spalte 3/3 | Zeile 93001/964586 | erstellt: 186002 | Dauer: 0s
# Spalte 3/3 | Zeile 94001/964586 | erstellt: 188002 | Dauer: 0s
# Spalte 3/3 | Zeile 95001/964586 | erstellt: 190002 | Dauer: 0s
# Spalte 3/3 | Zeile 96001/964586 | erstellt: 192002 | Dauer: 0s
# Spalte 3/3 | Zeile 97001/964586 | erstellt: 194002 | Dauer: 0s
# Spalte 3/3 | Zeile 98001/964586 | erstellt: 196002 | Dauer: 0s
# Spalte 3/3 | Zeile 99001/964586 | erstellt: 198002 | Dauer: 0s
# Spalte 3/3 | Zeile 100001/964586 | erstellt: 200002 | Dauer: 0s
# Spalte 3/3 | Zeile 101001/964586 | erstellt: 202002 | Dauer: 0s
# Spalte 3/3 | Zeile 102001/964586 | erstellt: 204002 | Dauer: 0s
# Spalte 3/3 | Zeile 103001/964586 | erstellt: 206002 | Dauer: 0s
# Spalte 3/3 | Zeile 104001/964586 | erstellt: 208002 | Dauer: 0s
# Spalte 3/3 | Zeile 105001/964586 | erstellt: 210002 | Dauer: 0s
# Spalte 3/3 | Zeile 106001/964586 | erstellt: 212002 | Dauer: 0s
# Spalte 3/3 | Zeile 107001/964586 | erstellt: 214002 | Dauer: 0s
# Spalte 3/3 | Zeile 108001/964586 | erstellt: 216002 | Dauer: 0s
# Spalte 3/3 | Zeile 109001/964586 | erstellt: 218002 | Dauer: 0s
# Spalte 3/3 | Zeile 110001/964586 | erstellt: 220002 | Dauer: 0s
# Spalte 3/3 | Zeile 111001/964586 | erstellt: 222002 | Dauer: 0s
# Spalte 3/3 | Zeile 112001/964586 | erstellt: 224002 | Dauer: 0s
# Spalte 3/3 | Zeile 113001/964586 | erstellt: 226002 | Dauer: 0s
# Spalte 3/3 | Zeile 114001/964586 | erstellt: 228002 | Dauer: 0s
# Spalte 3/3 | Zeile 115001/964586 | erstellt: 230002 | Dauer: 0s
# Spalte 3/3 | Zeile 116001/964586 | erstellt: 232002 | Dauer: 0s
# Spalte 3/3 | Zeile 117001/964586 | erstellt: 234002 | Dauer: 0s
# Spalte 3/3 | Zeile 118001/964586 | erstellt: 236002 | Dauer: 0s
# Spalte 3/3 | Zeile 119001/964586 | erstellt: 238002 | Dauer: 0s
# Spalte 3/3 | Zeile 120001/964586 | erstellt: 240002 | Dauer: 0s
# Spalte 3/3 | Zeile 121001/964586 | erstellt: 242002 | Dauer: 0s
# Spalte 3/3 | Zeile 122001/964586 | erstellt: 244002 | Dauer: 0s
# Spalte 3/3 | Zeile 123001/964586 | erstellt: 246002 | Dauer: 0s
# Spalte 3/3 | Zeile 124001/964586 | erstellt: 248002 | Dauer: 0s
# Spalte 3/3 | Zeile 125001/964586 | erstellt: 250002 | Dauer: 0s
# Spalte 3/3 | Zeile 126001/964586 | erstellt: 252002 | Dauer: 0s
# Spalte 3/3 | Zeile 127001/964586 | erstellt: 254002 | Dauer: 0s
# Spalte 3/3 | Zeile 128001/964586 | erstellt: 256002 | Dauer: 0s
# Spalte 3/3 | Zeile 129001/964586 | erstellt: 258002 | Dauer: 0s
# Spalte 3/3 | Zeile 130001/964586 | erstellt: 260002 | Dauer: 0s
# Spalte 3/3 | Zeile 131001/964586 | erstellt: 262002 | Dauer: 0s
# Spalte 3/3 | Zeile 132001/964586 | erstellt: 264002 | Dauer: 0s
# Spalte 3/3 | Zeile 133001/964586 | erstellt: 266002 | Dauer: 0s
# Spalte 3/3 | Zeile 134001/964586 | erstellt: 268002 | Dauer: 0s
# Spalte 3/3 | Zeile 135001/964586 | erstellt: 270002 | Dauer: 0s
# Spalte 3/3 | Zeile 136001/964586 | erstellt: 272002 | Dauer: 0s
# Spalte 3/3 | Zeile 137001/964586 | erstellt: 274002 | Dauer: 0s
# Spalte 3/3 | Zeile 138001/964586 | erstellt: 276002 | Dauer: 0s
# Spalte 3/3 | Zeile 139001/964586 | erstellt: 278002 | Dauer: 0s
# Spalte 3/3 | Zeile 140001/964586 | erstellt: 280002 | Dauer: 0s
# Spalte 3/3 | Zeile 141001/964586 | erstellt: 282002 | Dauer: 0s
# Spalte 3/3 | Zeile 142001/964586 | erstellt: 284002 | Dauer: 0s
# Spalte 3/3 | Zeile 143001/964586 | erstellt: 286002 | Dauer: 0s
# Spalte 3/3 | Zeile 144001/964586 | erstellt: 288002 | Dauer: 0s
# Spalte 3/3 | Zeile 145001/964586 | erstellt: 290002 | Dauer: 0s
# Spalte 3/3 | Zeile 146001/964586 | erstellt: 292002 | Dauer: 0s
# Spalte 3/3 | Zeile 147001/964586 | erstellt: 294002 | Dauer: 0s
# Spalte 3/3 | Zeile 148001/964586 | erstellt: 296002 | Dauer: 0s
# Spalte 3/3 | Zeile 149001/964586 | erstellt: 298002 | Dauer: 0s
# Spalte 3/3 | Zeile 150001/964586 | erstellt: 300002 | Dauer: 0s
# Spalte 3/3 | Zeile 151001/964586 | erstellt: 302002 | Dauer: 0s
# Spalte 3/3 | Zeile 152001/964586 | erstellt: 304002 | Dauer: 0s
# Spalte 3/3 | Zeile 153001/964586 | erstellt: 306002 | Dauer: 0s
# Spalte 3/3 | Zeile 154001/964586 | erstellt: 308002 | Dauer: 0s
# Spalte 3/3 | Zeile 155001/964586 | erstellt: 310002 | Dauer: 0s
# Spalte 3/3 | Zeile 156001/964586 | erstellt: 312002 | Dauer: 0s
# Spalte 3/3 | Zeile 157001/964586 | erstellt: 314002 | Dauer: 1s
# Spalte 3/3 | Zeile 158001/964586 | erstellt: 316002 | Dauer: 0s
# Spalte 3/3 | Zeile 159001/964586 | erstellt: 318002 | Dauer: 0s
# Spalte 3/3 | Zeile 160001/964586 | erstellt: 320002 | Dauer: 0s
# Spalte 3/3 | Zeile 161001/964586 | erstellt: 322002 | Dauer: 0s
# Spalte 3/3 | Zeile 162001/964586 | erstellt: 324002 | Dauer: 0s
# Spalte 3/3 | Zeile 163001/964586 | erstellt: 326002 | Dauer: 0s
# Spalte 3/3 | Zeile 164001/964586 | erstellt: 328002 | Dauer: 0s
# Spalte 3/3 | Zeile 165001/964586 | erstellt: 330002 | Dauer: 0s
# Spalte 3/3 | Zeile 166001/964586 | erstellt: 332002 | Dauer: 0s
# Spalte 3/3 | Zeile 167001/964586 | erstellt: 334002 | Dauer: 0s
# Spalte 3/3 | Zeile 168001/964586 | erstellt: 336002 | Dauer: 0s
# Spalte 3/3 | Zeile 169001/964586 | erstellt: 338002 | Dauer: 0s
# Spalte 3/3 | Zeile 170001/964586 | erstellt: 340002 | Dauer: 0s
# Spalte 3/3 | Zeile 171001/964586 | erstellt: 342002 | Dauer: 0s
# Spalte 3/3 | Zeile 172001/964586 | erstellt: 344002 | Dauer: 0s
# Spalte 3/3 | Zeile 173001/964586 | erstellt: 346002 | Dauer: 0s
# Spalte 3/3 | Zeile 174001/964586 | erstellt: 348002 | Dauer: 0s
# Spalte 3/3 | Zeile 175001/964586 | erstellt: 350002 | Dauer: 0s
# Spalte 3/3 | Zeile 176001/964586 | erstellt: 352002 | Dauer: 0s
# Spalte 3/3 | Zeile 177001/964586 | erstellt: 354002 | Dauer: 0s
# Spalte 3/3 | Zeile 178001/964586 | erstellt: 356002 | Dauer: 0s
# Spalte 3/3 | Zeile 179001/964586 | erstellt: 358002 | Dauer: 0s
# Spalte 3/3 | Zeile 180001/964586 | erstellt: 360002 | Dauer: 0s
# Spalte 3/3 | Zeile 181001/964586 | erstellt: 362002 | Dauer: 0s
# Spalte 3/3 | Zeile 182001/964586 | erstellt: 364002 | Dauer: 0s
# Spalte 3/3 | Zeile 183001/964586 | erstellt: 366002 | Dauer: 0s
# Spalte 3/3 | Zeile 184001/964586 | erstellt: 368002 | Dauer: 0s
# Spalte 3/3 | Zeile 185001/964586 | erstellt: 370002 | Dauer: 0s
# Spalte 3/3 | Zeile 186001/964586 | erstellt: 372002 | Dauer: 0s
# Spalte 3/3 | Zeile 187001/964586 | erstellt: 374002 | Dauer: 0s
# Spalte 3/3 | Zeile 188001/964586 | erstellt: 376002 | Dauer: 0s
# Spalte 3/3 | Zeile 189001/964586 | erstellt: 378002 | Dauer: 0s
# Spalte 3/3 | Zeile 190001/964586 | erstellt: 380002 | Dauer: 0s
# Spalte 3/3 | Zeile 191001/964586 | erstellt: 382002 | Dauer: 0s
# Spalte 3/3 | Zeile 192001/964586 | erstellt: 384002 | Dauer: 0s
# Spalte 3/3 | Zeile 193001/964586 | erstellt: 386002 | Dauer: 0s
# Spalte 3/3 | Zeile 194001/964586 | erstellt: 388002 | Dauer: 0s
# Spalte 3/3 | Zeile 195001/964586 | erstellt: 390002 | Dauer: 0s
# Spalte 3/3 | Zeile 196001/964586 | erstellt: 392002 | Dauer: 0s
# Spalte 3/3 | Zeile 197001/964586 | erstellt: 394002 | Dauer: 0s
# Spalte 3/3 | Zeile 198001/964586 | erstellt: 396002 | Dauer: 0s
# Spalte 3/3 | Zeile 199001/964586 | erstellt: 398002 | Dauer: 0s
# Spalte 3/3 | Zeile 200001/964586 | erstellt: 400002 | Dauer: 0s
# Spalte 3/3 | Zeile 201001/964586 | erstellt: 402002 | Dauer: 0s
# Spalte 3/3 | Zeile 202001/964586 | erstellt: 404002 | Dauer: 0s
# Spalte 3/3 | Zeile 203001/964586 | erstellt: 406002 | Dauer: 0s
# Spalte 3/3 | Zeile 204001/964586 | erstellt: 408002 | Dauer: 0s
# Spalte 3/3 | Zeile 205001/964586 | erstellt: 410002 | Dauer: 0s
# Spalte 3/3 | Zeile 206001/964586 | erstellt: 412002 | Dauer: 0s
# Spalte 3/3 | Zeile 207001/964586 | erstellt: 414002 | Dauer: 0s
# Spalte 3/3 | Zeile 208001/964586 | erstellt: 416002 | Dauer: 0s
# Spalte 3/3 | Zeile 209001/964586 | erstellt: 418002 | Dauer: 0s
# Spalte 3/3 | Zeile 210001/964586 | erstellt: 420002 | Dauer: 0s
# Spalte 3/3 | Zeile 211001/964586 | erstellt: 422002 | Dauer: 0s
# Spalte 3/3 | Zeile 212001/964586 | erstellt: 424002 | Dauer: 0s
# Spalte 3/3 | Zeile 213001/964586 | erstellt: 426002 | Dauer: 1s
# Spalte 3/3 | Zeile 214001/964586 | erstellt: 428002 | Dauer: 0s
# Spalte 3/3 | Zeile 215001/964586 | erstellt: 430002 | Dauer: 0s
# Spalte 3/3 | Zeile 216001/964586 | erstellt: 432002 | Dauer: 0s
# Spalte 3/3 | Zeile 217001/964586 | erstellt: 434002 | Dauer: 0s
# Spalte 3/3 | Zeile 218001/964586 | erstellt: 436002 | Dauer: 0s
# Spalte 3/3 | Zeile 219001/964586 | erstellt: 438002 | Dauer: 0s
# Spalte 3/3 | Zeile 220001/964586 | erstellt: 440002 | Dauer: 0s
# Spalte 3/3 | Zeile 221001/964586 | erstellt: 442002 | Dauer: 0s
# Spalte 3/3 | Zeile 222001/964586 | erstellt: 444002 | Dauer: 0s
# Spalte 3/3 | Zeile 223001/964586 | erstellt: 446002 | Dauer: 0s
# Spalte 3/3 | Zeile 224001/964586 | erstellt: 448002 | Dauer: 0s
# Spalte 3/3 | Zeile 225001/964586 | erstellt: 450002 | Dauer: 0s
# Spalte 3/3 | Zeile 226001/964586 | erstellt: 452002 | Dauer: 0s
# Spalte 3/3 | Zeile 227001/964586 | erstellt: 454002 | Dauer: 0s
# Spalte 3/3 | Zeile 228001/964586 | erstellt: 456002 | Dauer: 0s
# Spalte 3/3 | Zeile 229001/964586 | erstellt: 458002 | Dauer: 0s
# Spalte 3/3 | Zeile 230001/964586 | erstellt: 460002 | Dauer: 0s
# Spalte 3/3 | Zeile 231001/964586 | erstellt: 462002 | Dauer: 0s
# Spalte 3/3 | Zeile 232001/964586 | erstellt: 464002 | Dauer: 0s
# Spalte 3/3 | Zeile 233001/964586 | erstellt: 466002 | Dauer: 0s
# Spalte 3/3 | Zeile 234001/964586 | erstellt: 468002 | Dauer: 0s
# Spalte 3/3 | Zeile 235001/964586 | erstellt: 470002 | Dauer: 0s
# Spalte 3/3 | Zeile 236001/964586 | erstellt: 472002 | Dauer: 0s
# Spalte 3/3 | Zeile 237001/964586 | erstellt: 474002 | Dauer: 0s
# Spalte 3/3 | Zeile 238001/964586 | erstellt: 476002 | Dauer: 0s
# Spalte 3/3 | Zeile 239001/964586 | erstellt: 478002 | Dauer: 0s
# Spalte 3/3 | Zeile 240001/964586 | erstellt: 480002 | Dauer: 0s
# Spalte 3/3 | Zeile 241001/964586 | erstellt: 482002 | Dauer: 0s
# Spalte 3/3 | Zeile 242001/964586 | erstellt: 484002 | Dauer: 0s
# Spalte 3/3 | Zeile 243001/964586 | erstellt: 486002 | Dauer: 0s
# Spalte 3/3 | Zeile 244001/964586 | erstellt: 488002 | Dauer: 0s
# Spalte 3/3 | Zeile 245001/964586 | erstellt: 490002 | Dauer: 0s
# Spalte 3/3 | Zeile 246001/964586 | erstellt: 492002 | Dauer: 0s
# Spalte 3/3 | Zeile 247001/964586 | erstellt: 494002 | Dauer: 0s
# Spalte 3/3 | Zeile 248001/964586 | erstellt: 496002 | Dauer: 0s
# Spalte 3/3 | Zeile 249001/964586 | erstellt: 498002 | Dauer: 0s
# Spalte 3/3 | Zeile 250001/964586 | erstellt: 500002 | Dauer: 0s
# Spalte 3/3 | Zeile 251001/964586 | erstellt: 502002 | Dauer: 0s
# Spalte 3/3 | Zeile 252001/964586 | erstellt: 504002 | Dauer: 0s
# Spalte 3/3 | Zeile 253001/964586 | erstellt: 506002 | Dauer: 0s
# Spalte 3/3 | Zeile 254001/964586 | erstellt: 508002 | Dauer: 0s
# Spalte 3/3 | Zeile 255001/964586 | erstellt: 510002 | Dauer: 0s
# Spalte 3/3 | Zeile 256001/964586 | erstellt: 512002 | Dauer: 0s
# Spalte 3/3 | Zeile 257001/964586 | erstellt: 514002 | Dauer: 0s
# Spalte 3/3 | Zeile 258001/964586 | erstellt: 516002 | Dauer: 0s
# Spalte 3/3 | Zeile 259001/964586 | erstellt: 518002 | Dauer: 0s
# Spalte 3/3 | Zeile 260001/964586 | erstellt: 520002 | Dauer: 0s
# Spalte 3/3 | Zeile 261001/964586 | erstellt: 522002 | Dauer: 0s
# Spalte 3/3 | Zeile 262001/964586 | erstellt: 524002 | Dauer: 0s
# Spalte 3/3 | Zeile 263001/964586 | erstellt: 526002 | Dauer: 0s
# Spalte 3/3 | Zeile 264001/964586 | erstellt: 528002 | Dauer: 0s
# Spalte 3/3 | Zeile 265001/964586 | erstellt: 530002 | Dauer: 0s
# Spalte 3/3 | Zeile 266001/964586 | erstellt: 532002 | Dauer: 0s
# Spalte 3/3 | Zeile 267001/964586 | erstellt: 534002 | Dauer: 0s
# Spalte 3/3 | Zeile 268001/964586 | erstellt: 536002 | Dauer: 0s
# Spalte 3/3 | Zeile 269001/964586 | erstellt: 538002 | Dauer: 0s
# Spalte 3/3 | Zeile 270001/964586 | erstellt: 540002 | Dauer: 0s
# Spalte 3/3 | Zeile 271001/964586 | erstellt: 542002 | Dauer: 0s
# Spalte 3/3 | Zeile 272001/964586 | erstellt: 544002 | Dauer: 0s
# Spalte 3/3 | Zeile 273001/964586 | erstellt: 546002 | Dauer: 0s
# Spalte 3/3 | Zeile 274001/964586 | erstellt: 548002 | Dauer: 0s
# Spalte 3/3 | Zeile 275001/964586 | erstellt: 550002 | Dauer: 0s
# Spalte 3/3 | Zeile 276001/964586 | erstellt: 552002 | Dauer: 0s
# Spalte 3/3 | Zeile 277001/964586 | erstellt: 554002 | Dauer: 0s
# Spalte 3/3 | Zeile 278001/964586 | erstellt: 556002 | Dauer: 0s
# Spalte 3/3 | Zeile 279001/964586 | erstellt: 558002 | Dauer: 0s
# Spalte 3/3 | Zeile 280001/964586 | erstellt: 560002 | Dauer: 0s
# Spalte 3/3 | Zeile 281001/964586 | erstellt: 562002 | Dauer: 0s
# Spalte 3/3 | Zeile 282001/964586 | erstellt: 564002 | Dauer: 0s
# Spalte 3/3 | Zeile 283001/964586 | erstellt: 566002 | Dauer: 0s
# Spalte 3/3 | Zeile 284001/964586 | erstellt: 568002 | Dauer: 1s
# Spalte 3/3 | Zeile 285001/964586 | erstellt: 570002 | Dauer: 0s
# Spalte 3/3 | Zeile 286001/964586 | erstellt: 572002 | Dauer: 0s
# Spalte 3/3 | Zeile 287001/964586 | erstellt: 574002 | Dauer: 0s
# Spalte 3/3 | Zeile 288001/964586 | erstellt: 576002 | Dauer: 0s
# Spalte 3/3 | Zeile 289001/964586 | erstellt: 578002 | Dauer: 0s
# Spalte 3/3 | Zeile 290001/964586 | erstellt: 580002 | Dauer: 0s
# Spalte 3/3 | Zeile 291001/964586 | erstellt: 582002 | Dauer: 0s
# Spalte 3/3 | Zeile 292001/964586 | erstellt: 584002 | Dauer: 0s
# Spalte 3/3 | Zeile 293001/964586 | erstellt: 586002 | Dauer: 0s
# Spalte 3/3 | Zeile 294001/964586 | erstellt: 588002 | Dauer: 0s
# Spalte 3/3 | Zeile 295001/964586 | erstellt: 590002 | Dauer: 0s
# Spalte 3/3 | Zeile 296001/964586 | erstellt: 592002 | Dauer: 0s
# Spalte 3/3 | Zeile 297001/964586 | erstellt: 594002 | Dauer: 0s
# Spalte 3/3 | Zeile 298001/964586 | erstellt: 596002 | Dauer: 0s
# Spalte 3/3 | Zeile 299001/964586 | erstellt: 598002 | Dauer: 0s
# Spalte 3/3 | Zeile 300001/964586 | erstellt: 600002 | Dauer: 0s
# Spalte 3/3 | Zeile 301001/964586 | erstellt: 602002 | Dauer: 0s
# Spalte 3/3 | Zeile 302001/964586 | erstellt: 604002 | Dauer: 0s
# Spalte 3/3 | Zeile 303001/964586 | erstellt: 606002 | Dauer: 0s
# Spalte 3/3 | Zeile 304001/964586 | erstellt: 608002 | Dauer: 0s
# Spalte 3/3 | Zeile 305001/964586 | erstellt: 610002 | Dauer: 0s
# Spalte 3/3 | Zeile 306001/964586 | erstellt: 612002 | Dauer: 0s
# Spalte 3/3 | Zeile 307001/964586 | erstellt: 614002 | Dauer: 0s
# Spalte 3/3 | Zeile 308001/964586 | erstellt: 616002 | Dauer: 0s
# Spalte 3/3 | Zeile 309001/964586 | erstellt: 618002 | Dauer: 0s
# Spalte 3/3 | Zeile 310001/964586 | erstellt: 620002 | Dauer: 0s
# Spalte 3/3 | Zeile 311001/964586 | erstellt: 622002 | Dauer: 0s
# Spalte 3/3 | Zeile 312001/964586 | erstellt: 624002 | Dauer: 0s
# Spalte 3/3 | Zeile 313001/964586 | erstellt: 626002 | Dauer: 0s
# Spalte 3/3 | Zeile 314001/964586 | erstellt: 628002 | Dauer: 0s
# Spalte 3/3 | Zeile 315001/964586 | erstellt: 630002 | Dauer: 0s
# Spalte 3/3 | Zeile 316001/964586 | erstellt: 632002 | Dauer: 0s
# Spalte 3/3 | Zeile 317001/964586 | erstellt: 634002 | Dauer: 0s
# Spalte 3/3 | Zeile 318001/964586 | erstellt: 636002 | Dauer: 0s
# Spalte 3/3 | Zeile 319001/964586 | erstellt: 638002 | Dauer: 0s
# Spalte 3/3 | Zeile 320001/964586 | erstellt: 640002 | Dauer: 0s
# Spalte 3/3 | Zeile 321001/964586 | erstellt: 642002 | Dauer: 0s
# Spalte 3/3 | Zeile 322001/964586 | erstellt: 644002 | Dauer: 0s
# Spalte 3/3 | Zeile 323001/964586 | erstellt: 646002 | Dauer: 0s
# Spalte 3/3 | Zeile 324001/964586 | erstellt: 648002 | Dauer: 0s
# Spalte 3/3 | Zeile 325001/964586 | erstellt: 650002 | Dauer: 0s
# Spalte 3/3 | Zeile 326001/964586 | erstellt: 652002 | Dauer: 0s
# Spalte 3/3 | Zeile 327001/964586 | erstellt: 654002 | Dauer: 0s
# Spalte 3/3 | Zeile 328001/964586 | erstellt: 656002 | Dauer: 0s
# Spalte 3/3 | Zeile 329001/964586 | erstellt: 658002 | Dauer: 0s
# Spalte 3/3 | Zeile 330001/964586 | erstellt: 660002 | Dauer: 0s
# Spalte 3/3 | Zeile 331001/964586 | erstellt: 662002 | Dauer: 0s
# Spalte 3/3 | Zeile 332001/964586 | erstellt: 664002 | Dauer: 0s
# Spalte 3/3 | Zeile 333001/964586 | erstellt: 666002 | Dauer: 0s
# Spalte 3/3 | Zeile 334001/964586 | erstellt: 668002 | Dauer: 0s
# Spalte 3/3 | Zeile 335001/964586 | erstellt: 670002 | Dauer: 0s
# Spalte 3/3 | Zeile 336001/964586 | erstellt: 672002 | Dauer: 0s
# Spalte 3/3 | Zeile 337001/964586 | erstellt: 674002 | Dauer: 0s
# Spalte 3/3 | Zeile 338001/964586 | erstellt: 676002 | Dauer: 0s
# Spalte 3/3 | Zeile 339001/964586 | erstellt: 678002 | Dauer: 0s
# Spalte 3/3 | Zeile 340001/964586 | erstellt: 680002 | Dauer: 0s
# Spalte 3/3 | Zeile 341001/964586 | erstellt: 682002 | Dauer: 0s
# Spalte 3/3 | Zeile 342001/964586 | erstellt: 684002 | Dauer: 0s
# Spalte 3/3 | Zeile 343001/964586 | erstellt: 686002 | Dauer: 0s
# Spalte 3/3 | Zeile 344001/964586 | erstellt: 688002 | Dauer: 0s
# Spalte 3/3 | Zeile 345001/964586 | erstellt: 690002 | Dauer: 0s
# Spalte 3/3 | Zeile 346001/964586 | erstellt: 692002 | Dauer: 0s
# Spalte 3/3 | Zeile 347001/964586 | erstellt: 694002 | Dauer: 0s
# Spalte 3/3 | Zeile 348001/964586 | erstellt: 696002 | Dauer: 0s
# Spalte 3/3 | Zeile 349001/964586 | erstellt: 698002 | Dauer: 0s
# Spalte 3/3 | Zeile 350001/964586 | erstellt: 700002 | Dauer: 0s
# Spalte 3/3 | Zeile 351001/964586 | erstellt: 702002 | Dauer: 0s
# Spalte 3/3 | Zeile 352001/964586 | erstellt: 704002 | Dauer: 0s
# Spalte 3/3 | Zeile 353001/964586 | erstellt: 706002 | Dauer: 0s
# Spalte 3/3 | Zeile 354001/964586 | erstellt: 708002 | Dauer: 0s
# Spalte 3/3 | Zeile 355001/964586 | erstellt: 710002 | Dauer: 0s
# Spalte 3/3 | Zeile 356001/964586 | erstellt: 712002 | Dauer: 0s
# Spalte 3/3 | Zeile 357001/964586 | erstellt: 714002 | Dauer: 2s
# Spalte 3/3 | Zeile 358001/964586 | erstellt: 716002 | Dauer: 0s
# Spalte 3/3 | Zeile 359001/964586 | erstellt: 718002 | Dauer: 0s
# Spalte 3/3 | Zeile 360001/964586 | erstellt: 720002 | Dauer: 0s
# Spalte 3/3 | Zeile 361001/964586 | erstellt: 722002 | Dauer: 0s
# Spalte 3/3 | Zeile 362001/964586 | erstellt: 724002 | Dauer: 0s
# Spalte 3/3 | Zeile 363001/964586 | erstellt: 726002 | Dauer: 0s
# Spalte 3/3 | Zeile 364001/964586 | erstellt: 728002 | Dauer: 0s
# Spalte 3/3 | Zeile 365001/964586 | erstellt: 730002 | Dauer: 0s
# Spalte 3/3 | Zeile 366001/964586 | erstellt: 732002 | Dauer: 0s
# Spalte 3/3 | Zeile 367001/964586 | erstellt: 734002 | Dauer: 0s
# Spalte 3/3 | Zeile 368001/964586 | erstellt: 736002 | Dauer: 0s
# Spalte 3/3 | Zeile 369001/964586 | erstellt: 738002 | Dauer: 0s
# Spalte 3/3 | Zeile 370001/964586 | erstellt: 740002 | Dauer: 0s
# Spalte 3/3 | Zeile 371001/964586 | erstellt: 742002 | Dauer: 0s
# Spalte 3/3 | Zeile 372001/964586 | erstellt: 744002 | Dauer: 0s
# Spalte 3/3 | Zeile 373001/964586 | erstellt: 746002 | Dauer: 0s
# Spalte 3/3 | Zeile 374001/964586 | erstellt: 748002 | Dauer: 0s
# Spalte 3/3 | Zeile 375001/964586 | erstellt: 750002 | Dauer: 0s
# Spalte 3/3 | Zeile 376001/964586 | erstellt: 752002 | Dauer: 0s
# Spalte 3/3 | Zeile 377001/964586 | erstellt: 754002 | Dauer: 0s
# Spalte 3/3 | Zeile 378001/964586 | erstellt: 756002 | Dauer: 0s
# Spalte 3/3 | Zeile 379001/964586 | erstellt: 758002 | Dauer: 0s
# Spalte 3/3 | Zeile 380001/964586 | erstellt: 760002 | Dauer: 0s
# Spalte 3/3 | Zeile 381001/964586 | erstellt: 762002 | Dauer: 0s
# Spalte 3/3 | Zeile 382001/964586 | erstellt: 764002 | Dauer: 0s
# Spalte 3/3 | Zeile 383001/964586 | erstellt: 766002 | Dauer: 0s
# Spalte 3/3 | Zeile 384001/964586 | erstellt: 768002 | Dauer: 0s
# Spalte 3/3 | Zeile 385001/964586 | erstellt: 770002 | Dauer: 0s
# Spalte 3/3 | Zeile 386001/964586 | erstellt: 772002 | Dauer: 0s
# Spalte 3/3 | Zeile 387001/964586 | erstellt: 774002 | Dauer: 0s
# Spalte 3/3 | Zeile 388001/964586 | erstellt: 776002 | Dauer: 0s
# Spalte 3/3 | Zeile 389001/964586 | erstellt: 778002 | Dauer: 0s
# Spalte 3/3 | Zeile 390001/964586 | erstellt: 780002 | Dauer: 0s
# Spalte 3/3 | Zeile 391001/964586 | erstellt: 782002 | Dauer: 0s
# Spalte 3/3 | Zeile 392001/964586 | erstellt: 784002 | Dauer: 0s
# Spalte 3/3 | Zeile 393001/964586 | erstellt: 786002 | Dauer: 0s
# Spalte 3/3 | Zeile 394001/964586 | erstellt: 788002 | Dauer: 0s
# Spalte 3/3 | Zeile 395001/964586 | erstellt: 790002 | Dauer: 0s
# Spalte 3/3 | Zeile 396001/964586 | erstellt: 792002 | Dauer: 0s
# Spalte 3/3 | Zeile 397001/964586 | erstellt: 794002 | Dauer: 0s
# Spalte 3/3 | Zeile 398001/964586 | erstellt: 796002 | Dauer: 0s
# Spalte 3/3 | Zeile 399001/964586 | erstellt: 798002 | Dauer: 0s
# Spalte 3/3 | Zeile 400001/964586 | erstellt: 800002 | Dauer: 0s
# Spalte 3/3 | Zeile 401001/964586 | erstellt: 802002 | Dauer: 0s
# Spalte 3/3 | Zeile 402001/964586 | erstellt: 804002 | Dauer: 0s
# Spalte 3/3 | Zeile 403001/964586 | erstellt: 806002 | Dauer: 0s
# Spalte 3/3 | Zeile 404001/964586 | erstellt: 808002 | Dauer: 0s
# Spalte 3/3 | Zeile 405001/964586 | erstellt: 810002 | Dauer: 0s
# Spalte 3/3 | Zeile 406001/964586 | erstellt: 812002 | Dauer: 0s
# Spalte 3/3 | Zeile 407001/964586 | erstellt: 814002 | Dauer: 0s
# Spalte 3/3 | Zeile 408001/964586 | erstellt: 816002 | Dauer: 0s
# ...
# Spalte 3/3 | Zeile 719001/964586 | erstellt: 1438002 | Dauer: 0s
# Spalte 3/3 | Zeile 720001/964586 | erstellt: 1440002 | Dauer: 0s
# Spalte 3/3 | Zeile 721001/964586 | erstellt: 1442002 | Dauer: 0s
# Spalte 3/3 | Zeile 722001/964586 | erstellt: 1444002 | Dauer: 0s
# Spalte 3/3 | Zeile 723001/964586 | erstellt: 1446002 | Dauer: 0s
# Spalte 3/3 | Zeile 724001/964586 | erstellt: 1448002 | Dauer: 0s
# Spalte 3/3 | Zeile 725001/964586 | erstellt: 1450002 | Dauer: 0s
# Spalte 3/3 | Zeile 726001/964586 | erstellt: 1452002 | Dauer: 0s
# Spalte 3/3 | Zeile 727001/964586 | erstellt: 1454002 | Dauer: 0s
# Spalte 3/3 | Zeile 728001/964586 | erstellt: 1456002 | Dauer: 0s
# Spalte 3/3 | Zeile 729001/964586 | erstellt: 1458002 | Dauer: 0s
# Spalte 3/3 | Zeile 730001/964586 | erstellt: 1460002 | Dauer: 0s
# Spalte 3/3 | Zeile 731001/964586 | erstellt: 1462002 | Dauer: 0s
# Spalte 3/3 | Zeile 732001/964586 | erstellt: 1464002 | Dauer: 0s
# Spalte 3/3 | Zeile 733001/964586 | erstellt: 1466002 | Dauer: 0s
# Spalte 3/3 | Zeile 734001/964586 | erstellt: 1468002 | Dauer: 0s
# Spalte 3/3 | Zeile 735001/964586 | erstellt: 1470002 | Dauer: 0s
# Spalte 3/3 | Zeile 736001/964586 | erstellt: 1472002 | Dauer: 0s
# Spalte 3/3 | Zeile 737001/964586 | erstellt: 1474002 | Dauer: 0s
# Spalte 3/3 | Zeile 738001/964586 | erstellt: 1476002 | Dauer: 0s
# Spalte 3/3 | Zeile 739001/964586 | erstellt: 1478002 | Dauer: 0s
# Spalte 3/3 | Zeile 740001/964586 | erstellt: 1480002 | Dauer: 0s
# Spalte 3/3 | Zeile 741001/964586 | erstellt: 1482002 | Dauer: 0s
# Spalte 3/3 | Zeile 742001/964586 | erstellt: 1484002 | Dauer: 0s
# Spalte 3/3 | Zeile 743001/964586 | erstellt: 1486002 | Dauer: 0s
# Spalte 3/3 | Zeile 744001/964586 | erstellt: 1488002 | Dauer: 0s
# Spalte 3/3 | Zeile 745001/964586 | erstellt: 1490002 | Dauer: 0s
# Spalte 3/3 | Zeile 746001/964586 | erstellt: 1492002 | Dauer: 0s
# Spalte 3/3 | Zeile 747001/964586 | erstellt: 1494002 | Dauer: 0s
# Spalte 3/3 | Zeile 748001/964586 | erstellt: 1496002 | Dauer: 0s
# Spalte 3/3 | Zeile 749001/964586 | erstellt: 1498002 | Dauer: 0s
# Spalte 3/3 | Zeile 750001/964586 | erstellt: 1500002 | Dauer: 0s
# Spalte 3/3 | Zeile 751001/964586 | erstellt: 1502002 | Dauer: 0s
# Spalte 3/3 | Zeile 752001/964586 | erstellt: 1504002 | Dauer: 0s
# Spalte 3/3 | Zeile 753001/964586 | erstellt: 1506002 | Dauer: 0s
# Spalte 3/3 | Zeile 754001/964586 | erstellt: 1508002 | Dauer: 0s
# Spalte 3/3 | Zeile 755001/964586 | erstellt: 1510002 | Dauer: 0s
# Spalte 3/3 | Zeile 756001/964586 | erstellt: 1512002 | Dauer: 0s
# Spalte 3/3 | Zeile 757001/964586 | erstellt: 1514002 | Dauer: 0s
# Spalte 3/3 | Zeile 758001/964586 | erstellt: 1516002 | Dauer: 0s
# Spalte 3/3 | Zeile 759001/964586 | erstellt: 1518002 | Dauer: 0s
# Spalte 3/3 | Zeile 760001/964586 | erstellt: 1520002 | Dauer: 0s
# Spalte 3/3 | Zeile 761001/964586 | erstellt: 1522002 | Dauer: 0s
# Spalte 3/3 | Zeile 762001/964586 | erstellt: 1524002 | Dauer: 0s
# Spalte 3/3 | Zeile 763001/964586 | erstellt: 1526002 | Dauer: 0s
# Spalte 3/3 | Zeile 764001/964586 | erstellt: 1528002 | Dauer: 0s
# Spalte 3/3 | Zeile 765001/964586 | erstellt: 1530002 | Dauer: 0s
# Spalte 3/3 | Zeile 766001/964586 | erstellt: 1532002 | Dauer: 0s
# Spalte 3/3 | Zeile 767001/964586 | erstellt: 1534002 | Dauer: 0s
# Spalte 3/3 | Zeile 768001/964586 | erstellt: 1536002 | Dauer: 0s
# Spalte 3/3 | Zeile 769001/964586 | erstellt: 1538002 | Dauer: 0s
# Spalte 3/3 | Zeile 770001/964586 | erstellt: 1540002 | Dauer: 0s
# Spalte 3/3 | Zeile 771001/964586 | erstellt: 1542002 | Dauer: 0s
# Spalte 3/3 | Zeile 772001/964586 | erstellt: 1544002 | Dauer: 0s
# Spalte 3/3 | Zeile 773001/964586 | erstellt: 1546002 | Dauer: 0s
# Spalte 3/3 | Zeile 774001/964586 | erstellt: 1548002 | Dauer: 0s
# Spalte 3/3 | Zeile 775001/964586 | erstellt: 1550002 | Dauer: 0s
# Spalte 3/3 | Zeile 776001/964586 | erstellt: 1552002 | Dauer: 0s
# Spalte 3/3 | Zeile 777001/964586 | erstellt: 1554002 | Dauer: 0s
# Spalte 3/3 | Zeile 778001/964586 | erstellt: 1556002 | Dauer: 0s
# Spalte 3/3 | Zeile 779001/964586 | erstellt: 1558002 | Dauer: 0s
# Spalte 3/3 | Zeile 780001/964586 | erstellt: 1560002 | Dauer: 0s
# Spalte 3/3 | Zeile 781001/964586 | erstellt: 1562002 | Dauer: 0s
# Spalte 3/3 | Zeile 782001/964586 | erstellt: 1564002 | Dauer: 0s
# Spalte 3/3 | Zeile 783001/964586 | erstellt: 1566002 | Dauer: 0s
# Spalte 3/3 | Zeile 784001/964586 | erstellt: 1568002 | Dauer: 0s
# Spalte 3/3 | Zeile 785001/964586 | erstellt: 1570002 | Dauer: 0s
# Spalte 3/3 | Zeile 786001/964586 | erstellt: 1572002 | Dauer: 0s
# Spalte 3/3 | Zeile 787001/964586 | erstellt: 1574002 | Dauer: 0s
# Spalte 3/3 | Zeile 788001/964586 | erstellt: 1576002 | Dauer: 0s
# Spalte 3/3 | Zeile 789001/964586 | erstellt: 1578002 | Dauer: 0s
# Spalte 3/3 | Zeile 790001/964586 | erstellt: 1580002 | Dauer: 0s
# Spalte 3/3 | Zeile 791001/964586 | erstellt: 1582002 | Dauer: 0s
# Spalte 3/3 | Zeile 792001/964586 | erstellt: 1584002 | Dauer: 0s
# Spalte 3/3 | Zeile 793001/964586 | erstellt: 1586002 | Dauer: 0s
# Spalte 3/3 | Zeile 794001/964586 | erstellt: 1588002 | Dauer: 0s
# Spalte 3/3 | Zeile 795001/964586 | erstellt: 1590002 | Dauer: 0s
# Spalte 3/3 | Zeile 796001/964586 | erstellt: 1592002 | Dauer: 0s
# Spalte 3/3 | Zeile 797001/964586 | erstellt: 1594002 | Dauer: 0s
# Spalte 3/3 | Zeile 798001/964586 | erstellt: 1596002 | Dauer: 0s
# Spalte 3/3 | Zeile 799001/964586 | erstellt: 1598002 | Dauer: 0s
# Spalte 3/3 | Zeile 800001/964586 | erstellt: 1600002 | Dauer: 0s
# Spalte 3/3 | Zeile 801001/964586 | erstellt: 1602002 | Dauer: 0s
# Spalte 3/3 | Zeile 802001/964586 | erstellt: 1604002 | Dauer: 0s
# Spalte 3/3 | Zeile 803001/964586 | erstellt: 1606002 | Dauer: 0s
# Spalte 3/3 | Zeile 804001/964586 | erstellt: 1608002 | Dauer: 0s
# Spalte 3/3 | Zeile 805001/964586 | erstellt: 1610002 | Dauer: 0s
# Spalte 3/3 | Zeile 806001/964586 | erstellt: 1612002 | Dauer: 0s
# Spalte 3/3 | Zeile 807001/964586 | erstellt: 1614002 | Dauer: 0s
# Spalte 3/3 | Zeile 808001/964586 | erstellt: 1616002 | Dauer: 0s
# Spalte 3/3 | Zeile 809001/964586 | erstellt: 1618002 | Dauer: 0s
# Spalte 3/3 | Zeile 810001/964586 | erstellt: 1620002 | Dauer: 0s
# Spalte 3/3 | Zeile 811001/964586 | erstellt: 1622002 | Dauer: 0s
# Spalte 3/3 | Zeile 812001/964586 | erstellt: 1624002 | Dauer: 0s
# Spalte 3/3 | Zeile 813001/964586 | erstellt: 1626002 | Dauer: 0s
# Spalte 3/3 | Zeile 814001/964586 | erstellt: 1628002 | Dauer: 0s
# Spalte 3/3 | Zeile 815001/964586 | erstellt: 1630002 | Dauer: 0s
# Spalte 3/3 | Zeile 816001/964586 | erstellt: 1632002 | Dauer: 0s
# Spalte 3/3 | Zeile 817001/964586 | erstellt: 1634002 | Dauer: 0s
# Spalte 3/3 | Zeile 818001/964586 | erstellt: 1636002 | Dauer: 0s
# Spalte 3/3 | Zeile 819001/964586 | erstellt: 1638002 | Dauer: 0s
# Spalte 3/3 | Zeile 820001/964586 | erstellt: 1640002 | Dauer: 0s
# Spalte 3/3 | Zeile 821001/964586 | erstellt: 1642002 | Dauer: 0s
# Spalte 3/3 | Zeile 822001/964586 | erstellt: 1644002 | Dauer: 0s
# Spalte 3/3 | Zeile 823001/964586 | erstellt: 1646002 | Dauer: 0s
# Spalte 3/3 | Zeile 824001/964586 | erstellt: 1648002 | Dauer: 0s
# Spalte 3/3 | Zeile 825001/964586 | erstellt: 1650002 | Dauer: 0s
# Spalte 3/3 | Zeile 826001/964586 | erstellt: 1652002 | Dauer: 0s
# Spalte 3/3 | Zeile 827001/964586 | erstellt: 1654002 | Dauer: 0s
# Spalte 3/3 | Zeile 828001/964586 | erstellt: 1656002 | Dauer: 0s
# Spalte 3/3 | Zeile 829001/964586 | erstellt: 1658002 | Dauer: 0s
# Spalte 3/3 | Zeile 830001/964586 | erstellt: 1660002 | Dauer: 0s
# Spalte 3/3 | Zeile 831001/964586 | erstellt: 1662002 | Dauer: 0s
# Spalte 3/3 | Zeile 832001/964586 | erstellt: 1664002 | Dauer: 0s
# Spalte 3/3 | Zeile 833001/964586 | erstellt: 1666002 | Dauer: 0s
# Spalte 3/3 | Zeile 834001/964586 | erstellt: 1668002 | Dauer: 0s
# Spalte 3/3 | Zeile 835001/964586 | erstellt: 1670002 | Dauer: 0s
# Spalte 3/3 | Zeile 836001/964586 | erstellt: 1672002 | Dauer: 0s
# Spalte 3/3 | Zeile 837001/964586 | erstellt: 1674002 | Dauer: 0s
# Spalte 3/3 | Zeile 838001/964586 | erstellt: 1676002 | Dauer: 0s
# Spalte 3/3 | Zeile 839001/964586 | erstellt: 1678002 | Dauer: 0s
# Spalte 3/3 | Zeile 840001/964586 | erstellt: 1680002 | Dauer: 0s
# Spalte 3/3 | Zeile 841001/964586 | erstellt: 1682002 | Dauer: 0s
# Spalte 3/3 | Zeile 842001/964586 | erstellt: 1684002 | Dauer: 0s
# Spalte 3/3 | Zeile 843001/964586 | erstellt: 1686002 | Dauer: 0s
# Spalte 3/3 | Zeile 844001/964586 | erstellt: 1688002 | Dauer: 0s
# Spalte 3/3 | Zeile 845001/964586 | erstellt: 1690002 | Dauer: 0s
# Spalte 3/3 | Zeile 846001/964586 | erstellt: 1692002 | Dauer: 0s
# Spalte 3/3 | Zeile 847001/964586 | erstellt: 1694002 | Dauer: 0s
# Spalte 3/3 | Zeile 848001/964586 | erstellt: 1696002 | Dauer: 0s
# Spalte 3/3 | Zeile 849001/964586 | erstellt: 1698002 | Dauer: 0s
# Spalte 3/3 | Zeile 850001/964586 | erstellt: 1700002 | Dauer: 0s
# Spalte 3/3 | Zeile 851001/964586 | erstellt: 1702002 | Dauer: 0s
# Spalte 3/3 | Zeile 852001/964586 | erstellt: 1704002 | Dauer: 0s
# Spalte 3/3 | Zeile 853001/964586 | erstellt: 1706002 | Dauer: 0s
# Spalte 3/3 | Zeile 854001/964586 | erstellt: 1708002 | Dauer: 0s
# Spalte 3/3 | Zeile 855001/964586 | erstellt: 1710002 | Dauer: 0s
# Spalte 3/3 | Zeile 856001/964586 | erstellt: 1712002 | Dauer: 0s
# Spalte 3/3 | Zeile 857001/964586 | erstellt: 1714002 | Dauer: 0s
# Spalte 3/3 | Zeile 858001/964586 | erstellt: 1716002 | Dauer: 0s
# Spalte 3/3 | Zeile 859001/964586 | erstellt: 1718002 | Dauer: 0s
# Spalte 3/3 | Zeile 860001/964586 | erstellt: 1720002 | Dauer: 0s
# Spalte 3/3 | Zeile 861001/964586 | erstellt: 1722002 | Dauer: 0s
# Spalte 3/3 | Zeile 862001/964586 | erstellt: 1724002 | Dauer: 0s
# Spalte 3/3 | Zeile 863001/964586 | erstellt: 1726002 | Dauer: 0s
# Spalte 3/3 | Zeile 864001/964586 | erstellt: 1728002 | Dauer: 0s
# Spalte 3/3 | Zeile 865001/964586 | erstellt: 1730002 | Dauer: 0s
# Spalte 3/3 | Zeile 866001/964586 | erstellt: 1732002 | Dauer: 0s
# Spalte 3/3 | Zeile 867001/964586 | erstellt: 1734002 | Dauer: 0s
# Spalte 3/3 | Zeile 868001/964586 | erstellt: 1736002 | Dauer: 0s
# Spalte 3/3 | Zeile 869001/964586 | erstellt: 1738002 | Dauer: 0s
# Spalte 3/3 | Zeile 870001/964586 | erstellt: 1740002 | Dauer: 0s
# Spalte 3/3 | Zeile 871001/964586 | erstellt: 1742002 | Dauer: 0s
# Spalte 3/3 | Zeile 872001/964586 | erstellt: 1744002 | Dauer: 0s
# Spalte 3/3 | Zeile 873001/964586 | erstellt: 1746002 | Dauer: 0s
# Spalte 3/3 | Zeile 874001/964586 | erstellt: 1748002 | Dauer: 0s
# Spalte 3/3 | Zeile 875001/964586 | erstellt: 1750002 | Dauer: 0s
# Spalte 3/3 | Zeile 876001/964586 | erstellt: 1752002 | Dauer: 0s
# Spalte 3/3 | Zeile 877001/964586 | erstellt: 1754002 | Dauer: 0s
# Spalte 3/3 | Zeile 878001/964586 | erstellt: 1756002 | Dauer: 0s
# Spalte 3/3 | Zeile 879001/964586 | erstellt: 1758002 | Dauer: 0s
# Spalte 3/3 | Zeile 880001/964586 | erstellt: 1760002 | Dauer: 4s
# Spalte 3/3 | Zeile 881001/964586 | erstellt: 1762002 | Dauer: 0s
# Spalte 3/3 | Zeile 882001/964586 | erstellt: 1764002 | Dauer: 0s
# Spalte 3/3 | Zeile 883001/964586 | erstellt: 1766002 | Dauer: 0s
# Spalte 3/3 | Zeile 884001/964586 | erstellt: 1768002 | Dauer: 0s
# Spalte 3/3 | Zeile 885001/964586 | erstellt: 1770002 | Dauer: 0s
# Spalte 3/3 | Zeile 886001/964586 | erstellt: 1772002 | Dauer: 0s
# Spalte 3/3 | Zeile 887001/964586 | erstellt: 1774002 | Dauer: 0s
# Spalte 3/3 | Zeile 888001/964586 | erstellt: 1776002 | Dauer: 0s
# Spalte 3/3 | Zeile 889001/964586 | erstellt: 1778002 | Dauer: 0s
# Spalte 3/3 | Zeile 890001/964586 | erstellt: 1780002 | Dauer: 0s
# Spalte 3/3 | Zeile 891001/964586 | erstellt: 1782002 | Dauer: 0s
# Spalte 3/3 | Zeile 892001/964586 | erstellt: 1784002 | Dauer: 0s
# Spalte 3/3 | Zeile 893001/964586 | erstellt: 1786002 | Dauer: 0s
# Spalte 3/3 | Zeile 894001/964586 | erstellt: 1788002 | Dauer: 0s
# Spalte 3/3 | Zeile 895001/964586 | erstellt: 1790002 | Dauer: 0s
# Spalte 3/3 | Zeile 896001/964586 | erstellt: 1792002 | Dauer: 0s
# Spalte 3/3 | Zeile 897001/964586 | erstellt: 1794002 | Dauer: 0s
# Spalte 3/3 | Zeile 898001/964586 | erstellt: 1796002 | Dauer: 0s
# Spalte 3/3 | Zeile 899001/964586 | erstellt: 1798002 | Dauer: 0s
# Spalte 3/3 | Zeile 900001/964586 | erstellt: 1800002 | Dauer: 0s
# Spalte 3/3 | Zeile 901001/964586 | erstellt: 1802002 | Dauer: 0s
# Spalte 3/3 | Zeile 902001/964586 | erstellt: 1804002 | Dauer: 0s
# Spalte 3/3 | Zeile 903001/964586 | erstellt: 1806002 | Dauer: 0s
# Spalte 3/3 | Zeile 904001/964586 | erstellt: 1808002 | Dauer: 0s
# Spalte 3/3 | Zeile 905001/964586 | erstellt: 1810002 | Dauer: 0s
# Spalte 3/3 | Zeile 906001/964586 | erstellt: 1812002 | Dauer: 0s
# Spalte 3/3 | Zeile 907001/964586 | erstellt: 1814002 | Dauer: 0s
# Spalte 3/3 | Zeile 908001/964586 | erstellt: 1816002 | Dauer: 0s
# Spalte 3/3 | Zeile 909001/964586 | erstellt: 1818002 | Dauer: 0s
# Spalte 3/3 | Zeile 910001/964586 | erstellt: 1820002 | Dauer: 0s
# Spalte 3/3 | Zeile 911001/964586 | erstellt: 1822002 | Dauer: 0s
# Spalte 3/3 | Zeile 912001/964586 | erstellt: 1824002 | Dauer: 0s
# Spalte 3/3 | Zeile 913001/964586 | erstellt: 1826002 | Dauer: 0s
# Spalte 3/3 | Zeile 914001/964586 | erstellt: 1828002 | Dauer: 0s
# Spalte 3/3 | Zeile 915001/964586 | erstellt: 1830002 | Dauer: 0s
# Spalte 3/3 | Zeile 916001/964586 | erstellt: 1832002 | Dauer: 0s
# Spalte 3/3 | Zeile 917001/964586 | erstellt: 1834002 | Dauer: 0s
# Spalte 3/3 | Zeile 918001/964586 | erstellt: 1836002 | Dauer: 0s
# Spalte 3/3 | Zeile 919001/964586 | erstellt: 1838002 | Dauer: 0s
# Spalte 3/3 | Zeile 920001/964586 | erstellt: 1840002 | Dauer: 0s
# Spalte 3/3 | Zeile 921001/964586 | erstellt: 1842002 | Dauer: 0s
# Spalte 3/3 | Zeile 922001/964586 | erstellt: 1844002 | Dauer: 0s
# Spalte 3/3 | Zeile 923001/964586 | erstellt: 1846002 | Dauer: 0s
# Spalte 3/3 | Zeile 924001/964586 | erstellt: 1848002 | Dauer: 0s
# Spalte 3/3 | Zeile 925001/964586 | erstellt: 1850002 | Dauer: 0s
# Spalte 3/3 | Zeile 926001/964586 | erstellt: 1852002 | Dauer: 0s
# Spalte 3/3 | Zeile 927001/964586 | erstellt: 1854002 | Dauer: 0s
# Spalte 3/3 | Zeile 928001/964586 | erstellt: 1856002 | Dauer: 0s
# Spalte 3/3 | Zeile 929001/964586 | erstellt: 1858002 | Dauer: 0s
# Spalte 3/3 | Zeile 930001/964586 | erstellt: 1860002 | Dauer: 0s
# Spalte 3/3 | Zeile 931001/964586 | erstellt: 1862002 | Dauer: 0s
# Spalte 3/3 | Zeile 932001/964586 | erstellt: 1864002 | Dauer: 0s
# Spalte 3/3 | Zeile 933001/964586 | erstellt: 1866002 | Dauer: 0s
# Spalte 3/3 | Zeile 934001/964586 | erstellt: 1868002 | Dauer: 0s
# Spalte 3/3 | Zeile 935001/964586 | erstellt: 1870002 | Dauer: 0s
# Spalte 3/3 | Zeile 936001/964586 | erstellt: 1872002 | Dauer: 0s
# Spalte 3/3 | Zeile 937001/964586 | erstellt: 1874002 | Dauer: 0s
# Spalte 3/3 | Zeile 938001/964586 | erstellt: 1876002 | Dauer: 0s
# Spalte 3/3 | Zeile 939001/964586 | erstellt: 1878002 | Dauer: 0s
# Spalte 3/3 | Zeile 940001/964586 | erstellt: 1880002 | Dauer: 0s
# Spalte 3/3 | Zeile 941001/964586 | erstellt: 1882002 | Dauer: 0s
# Spalte 3/3 | Zeile 942001/964586 | erstellt: 1884002 | Dauer: 0s
# Spalte 3/3 | Zeile 943001/964586 | erstellt: 1886002 | Dauer: 0s
# Spalte 3/3 | Zeile 944001/964586 | erstellt: 1888002 | Dauer: 0s
# Spalte 3/3 | Zeile 945001/964586 | erstellt: 1890002 | Dauer: 0s
# Spalte 3/3 | Zeile 946001/964586 | erstellt: 1892002 | Dauer: 0s
# Spalte 3/3 | Zeile 947001/964586 | erstellt: 1894002 | Dauer: 0s
# Spalte 3/3 | Zeile 948001/964586 | erstellt: 1896002 | Dauer: 0s
# Spalte 3/3 | Zeile 949001/964586 | erstellt: 1898002 | Dauer: 0s
# Spalte 3/3 | Zeile 950001/964586 | erstellt: 1900002 | Dauer: 0s
# Spalte 3/3 | Zeile 951001/964586 | erstellt: 1902002 | Dauer: 0s
# Spalte 3/3 | Zeile 952001/964586 | erstellt: 1904002 | Dauer: 0s
# Spalte 3/3 | Zeile 953001/964586 | erstellt: 1906002 | Dauer: 0s
# Spalte 3/3 | Zeile 954001/964586 | erstellt: 1908002 | Dauer: 0s
# Spalte 3/3 | Zeile 955001/964586 | erstellt: 1910002 | Dauer: 0s
# Spalte 3/3 | Zeile 956001/964586 | erstellt: 1912002 | Dauer: 0s
# Spalte 3/3 | Zeile 957001/964586 | erstellt: 1914002 | Dauer: 0s
# Spalte 3/3 | Zeile 958001/964586 | erstellt: 1916002 | Dauer: 0s
# Spalte 3/3 | Zeile 959001/964586 | erstellt: 1918002 | Dauer: 0s
# Spalte 3/3 | Zeile 960001/964586 | erstellt: 1920002 | Dauer: 0s
# Spalte 3/3 | Zeile 961001/964586 | erstellt: 1922002 | Dauer: 0s
# Spalte 3/3 | Zeile 962001/964586 | erstellt: 1924002 | Dauer: 0s
# Spalte 3/3 | Zeile 963001/964586 | erstellt: 1926002 | Dauer: 0s
# Spalte 3/3 | Zeile 964001/964586 | erstellt: 1928002 | Dauer: 0s

# %%
weights.describe()
# Out:
# count    2.892827e+06
# mean     1.250576e-02
# std      4.728741e-02
# min      2.439024e-03
# 25%      2.439024e-03
# 50%      4.878049e-03
# 75%      1.176471e-02
# max      1.000000e+00
# Name: weight, dtype: float64

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2892827 entries, 0 to 2892826
# Data columns (total 15 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   age             object
#  1   workclass       object
#  2   fnlwgt          int64
#  3   education       object
#  4   education-num   int64
#  5   marital-status  object
#  6   occupation      object
#  7   relationship    object
#  8   race            object
#  9   sex             object
#  10  capital-gain    int64
#  11  capital-loss    int64
#  12  hours-per-week  int64
#  13  native-country  object
#  14  income          int64
# dtypes: int64(6), object(9)
# memory usage: 331.1+ MB

# %%
y_train=data_train["income"]
data_train.drop("income", axis=1, inplace=True)
y_test=data_test["income"]
data_test.drop("income", axis=1, inplace=True)

# %%
#Alle Spalten vom Typ 'object' in Kategorien umwandeln
data_train['age'] = data_train['age'].astype('int64')
for col in data_train.select_dtypes(include='object').columns:
    print(col)
    data_original[col] = data_original[col].astype('category')
    data_train[col] = data_train[col].astype('category').cat.set_categories(data_original[col].cat.categories)
    data_test[col] = data_test[col].astype('category').cat.set_categories(data_original[col].cat.categories)
# Out:
# workclass
# education
# marital-status
# occupation
# relationship
# race
# sex
# native-country

# %%
data_train.shape, data_test.shape, y_train.shape, y_test.shape
# Out:
# ((2892827, 14), (9045, 14), (2892827,), (9045,))

# %%
import xgboost as xgb
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, ConfusionMatrixDisplay, f1_score

# %%
model = xgb.XGBClassifier(enable_categorical=True, n_estimators=40, max_depth=5)
model.fit(data_train,y_train, sample_weight=weights)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=40, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
#y_pred = model.predict(X_test)
prediction_xgbc=model.predict_proba(data_test)
lr_probs = prediction_xgbc[:, 1]
y_pred = (lr_probs > 0.5).astype(int)
cm_display = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_test,y_pred), display_labels=[0, 1])
cm_display.plot()
plt.show()

# %%
print("-------------------------------------------------------------------------")
print(f"The accuraccy score is: ------>>  {accuracy_score(y_test,y_pred)}")
print("-------------------------------------------------------------------------")
print(f"The Confusion Matrix is: ------>> \n{confusion_matrix(y_test,y_pred)}")
print("-------------------------------------------------------------------------")
print(f"The Classification Report is: ---->>\n {classification_report(y_test,y_pred)}")
print(f"F1-Score: {f1_score(y_test, y_pred)}")
# Out:
# -------------------------------------------------------------------------
# The accuraccy score is: ------>>  0.8681039248203427
# -------------------------------------------------------------------------
# The Confusion Matrix is: ------>>
# [[6434  406]
#  [ 787 1418]]
# -------------------------------------------------------------------------
# The Classification Report is: ---->>
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.92      6840
#            1       0.78      0.64      0.70      2205
#
#     accuracy                           0.87      9045
#    macro avg       0.83      0.79      0.81      9045
# weighted avg       0.86      0.87      0.86      9045
#
# F1-Score: 0.7038967485728469
